# %% [markdown]
# Proszę wybrać dane obrazowe, które wymagają rozwiązania problemu klasyfikacji, detekcji obiektów lub segmentacji. Należy zaimplementować modele oparte na sieciach neuronowych konwolucyjnych (CNN), eksperymentując z różnymi modelami, strukturami oraz technikami optymalizacji, augmentacji danych i transfer learningu. Proszę wyciągniać wnioski również w oparciu o wyniki wizualizacji. Kluczowym elementem będzie wykorzystanie wytrenowanych modeli, ich dostosowanie do konkretnego zadania i zbioru danych oraz ocena skuteczności metod optymalizacji i regularyzacji.
# Wysyłany do oceny notebook powinien mieć nazwę: GGSN_Imię_Nazwisko_Zad2.
