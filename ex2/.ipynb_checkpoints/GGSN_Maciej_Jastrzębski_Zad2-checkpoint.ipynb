# %% [markdown]
# # Klasyfikacja obrazow kart - CNN z optymalizacja, augmentacja i transfer learning
#
# Dataset: Cards Image Dataset (Kaggle)
#
# Zadania:
# - Klasyfikacja kart do 53 klas
# - Eksperymentowanie z rozna architektura CNN
# - Optymalizacja hyperparametrow
# - Augmentacja danych
# - Transfer learning (VGG16, VGG19, ResNet50, InceptionV3, MobileNetV2, EfficientNetB0)
# - Wizualizacje: filtry, mapy aktywacji, Grad-CAM, confusion matrix
# - Zapisywanie checkpointow
#
# https://www.kaggle.com/datasets/gpiosenka/cards-image-datasetclassification

# %% [markdown]
# ## 1. Importy i konfiguracja

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import json
from pathlib import Path

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Dense, Flatten, Dropout, 
    BatchNormalization, GlobalAveragePooling2D, Input
)
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import (
    ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
)
from tensorflow.keras.applications import (
    VGG16, VGG19, ResNet50, InceptionV3, MobileNetV2, EfficientNetB0
)

from sklearn.metrics import confusion_matrix, classification_report

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU available: {tf.config.list_physical_devices('GPU')}")

# Konfiguracja
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775214135.663483     591 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow version: 2.21.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Konfiguracja sciezek i parametrow

# %%
# Sciezki - dostosuj do swojego srodowiska
BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / '../data/cards-image-datasetclassification'
TRAIN_DIR = DATA_DIR / 'train'
VALID_DIR = DATA_DIR / 'valid'
TEST_DIR = DATA_DIR / 'test'

# Utworz katalogi na wyniki
RESULTS_DIR = BASE_DIR / 'results'
CHECKPOINTS_DIR = RESULTS_DIR / 'checkpoints'
PLOTS_DIR = RESULTS_DIR / 'plots'
LOGS_DIR = RESULTS_DIR / 'logs'

for directory in [RESULTS_DIR, CHECKPOINTS_DIR, PLOTS_DIR, LOGS_DIR]:
    directory.mkdir(exist_ok=True, parents=True)

print(f"Base directory: {BASE_DIR}")
print(f"Data directory: {DATA_DIR}")
print(f"Results directory: {RESULTS_DIR}")

# Sprawdz czy dane istnieja
if TRAIN_DIR.exists():
    classes = sorted([d.name for d in TRAIN_DIR.iterdir() if d.is_dir()])
    print(f"\nNumber of classes: {len(classes)}")
    print(f"Sample classes: {classes[:5]}")
else:
    print(f"\nWARNING: Training directory not found at {TRAIN_DIR}")
    print("Please download dataset from Kaggle and adjust DATA_DIR path")
# Out:
# Base directory: /home/chemik/studia/ggsn/agh_ggsn/ex2
# Data directory: /home/chemik/studia/ggsn/agh_ggsn/ex2/../data/cards-image-datasetclassification
# Results directory: /home/chemik/studia/ggsn/agh_ggsn/ex2/results
#
# Number of classes: 53
# Sample classes: ['ace of clubs', 'ace of diamonds', 'ace of hearts', 'ace of spades', 'eight of clubs']

# %%
# Parametry obrazow
IMG_HEIGHT = 224
IMG_WIDTH = 224
IMG_CHANNELS = 3
IMG_SIZE = (IMG_HEIGHT, IMG_WIDTH)

# Parametry treningu
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 0.001

# Liczba klas
if TRAIN_DIR.exists():
    NUM_CLASSES = len([d for d in TRAIN_DIR.iterdir() if d.is_dir()])
else:
    NUM_CLASSES = 53  # dla datasetu kart

print(f"Image size: {IMG_SIZE}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Number of classes: {NUM_CLASSES}")
# Out:
# Image size: (224, 224)
# Batch size: 32
# Number of classes: 53

# %% [markdown]
# ## 3. Eksploracja danych

# %%
# Analiza struktury datasetu
if TRAIN_DIR.exists():
    train_counts = {}
    for class_dir in TRAIN_DIR.iterdir():
        if class_dir.is_dir():
            count = len(list(class_dir.glob('*.jpg'))) + len(list(class_dir.glob('*.png')))
            train_counts[class_dir.name] = count
    
    print("Dataset statistics:")
    print(f"Total training images: {sum(train_counts.values())}")
    print(f"Images per class - min: {min(train_counts.values())}, max: {max(train_counts.values())}, mean: {np.mean(list(train_counts.values())):.1f}")
    
    # Wizualizacja rozkladu klas
    plt.figure(figsize=(16, 6))
    plt.bar(range(len(train_counts)), sorted(train_counts.values(), reverse=True))
    plt.xlabel('class index (sorted by count)')
    plt.ylabel('number of images')
    plt.title('training data distribution')
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / 'data_distribution.png', dpi=150, bbox_inches='tight')
    plt.show()
# Out:
# Dataset statistics:
# Total training images: 7624
# Images per class - min: 108, max: 181, mean: 143.8

# %%
# przykladowe obrazy
if TRAIN_DIR.exists():
    fig, axes = plt.subplots(4, 8, figsize=(20, 10))
    axes = axes.ravel()
    
    class_dirs = [d for d in TRAIN_DIR.iterdir() if d.is_dir()]
    sample_classes = np.random.choice(class_dirs, size=min(32, len(class_dirs)), replace=False)
    
    for idx, class_dir in enumerate(sample_classes):
        images = list(class_dir.glob('*.jpg')) + list(class_dir.glob('*.png'))
        if images:
            img_path = np.random.choice(images)
            img = load_img(img_path, target_size=IMG_SIZE)
            axes[idx].imshow(img)
            axes[idx].set_title(class_dir.name, fontsize=8)
            axes[idx].axis('off')
    
    plt.suptitle('sample images from dataset', fontsize=14, y=1.00)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / 'sample_images.png', dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## 4. Przygotowanie generatorow danych

# %%
# Generator bez augmentacji (baseline)
train_datagen_baseline = ImageDataGenerator(
    rescale=1./255
)

# Generator z augmentacja
train_datagen_augmented = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Generator walidacyjny i testowy
valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

print("Data generators created")
# Out:
# Data generators created

# %%
# Utworz generatory flow_from_directory
if TRAIN_DIR.exists():
    train_generator_baseline = train_datagen_baseline.flow_from_directory(
        TRAIN_DIR,
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        seed=42
    )
    
    train_generator_augmented = train_datagen_augmented.flow_from_directory(
        TRAIN_DIR,
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=True,
        seed=42
    )
    
    if VALID_DIR.exists():
        valid_generator = valid_datagen.flow_from_directory(
            VALID_DIR,
            target_size=IMG_SIZE,
            batch_size=BATCH_SIZE,
            class_mode='categorical',
            shuffle=False
        )
    
    if TEST_DIR.exists():
        test_generator = test_datagen.flow_from_directory(
            TEST_DIR,
            target_size=IMG_SIZE,
            batch_size=BATCH_SIZE,
            class_mode='categorical',
            shuffle=False
        )
    
    # Zapisz mapowanie klas
    class_indices = train_generator_baseline.class_indices
    with open(RESULTS_DIR / 'class_indices.json', 'w') as f:
        json.dump(class_indices, f, indent=2)
    
    print(f"\nClass indices saved to {RESULTS_DIR / 'class_indices.json'}")
    print(f"Total classes: {len(class_indices)}")
else:
    print("Data directories not found. Please adjust paths.")
# Out:
# Found 7624 images belonging to 53 classes.
# Found 7624 images belonging to 53 classes.
# Found 265 images belonging to 53 classes.
# Found 265 images belonging to 53 classes.
#
# Class indices saved to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/class_indices.json
# Total classes: 53

# %%
# Wizualizacja augmentacji
if TRAIN_DIR.exists():
    # Pobierz jeden obraz
    class_dirs = [d for d in TRAIN_DIR.iterdir() if d.is_dir()]
    sample_class = np.random.choice(class_dirs)
    images = list(sample_class.glob('*.jpg')) + list(sample_class.glob('*.png'))
    sample_image_path = np.random.choice(images)
    
    img = load_img(sample_image_path, target_size=IMG_SIZE)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    
    # Generuj augmentowane wersje
    fig, axes = plt.subplots(2, 5, figsize=(18, 7))
    axes = axes.ravel()
    
    axes[0].imshow(img)
    axes[0].set_title('original', fontsize=10)
    axes[0].axis('off')
    
    aug_gen = train_datagen_augmented.flow(img_array, batch_size=1)
    for i in range(1, 10):
        aug_img = next(aug_gen)[0]
        axes[i].imshow(aug_img)
        axes[i].set_title(f'augmented {i}', fontsize=10)
        axes[i].axis('off')
    
    plt.suptitle('data augmentation examples', fontsize=14)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / 'augmentation_examples.png', dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## 5. Model CNN od zera - baseline

# %%
def create_cnn_baseline():
    """Prosty model CNN jako baseline"""
    model = Sequential([
        Input(shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)),
        Conv2D(32, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        
        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    return model

model_baseline = create_cnn_baseline()
model_baseline.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model_baseline.summary()
# Out:
# /home/chemik/miniconda3/envs/ggsn_ex2/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1775214149.159126     591 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5561 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:0a:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    22,151,424 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 53)             │        13,621 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,258,293 (84.91 MB)
#  Trainable params: 22,258,293 (84.91 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def create_cnn_optimized():
    """Zoptymalizowany model CNN z batch normalization"""
    model = Sequential([
        Input(shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)),
        Conv2D(32, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(2, 2),
        Dropout(0.2),
        
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(2, 2),
        Dropout(0.3),
        
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(2, 2),
        Dropout(0.4),
        
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(2, 2),
        Dropout(0.5),
        
        Flatten(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(NUM_CLASSES, activation='softmax')
    ])
    
    return model

model_optimized = create_cnn_optimized()
model_optimized.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model_optimized.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 56, 56, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 28, 28, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │    25,690,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 53)             │        13,621 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,968,181 (102.88 MB)
#  Trainable params: 26,964,917 (102.86 MB)
#  Non-trainable params: 3,264 (12.75 KB)

# %% [markdown]
# ## 6. Callbacki i checkpointy

# %%
def get_callbacks(model_name):
    """Utworz callbacki dla modelu"""
    
    checkpoint = ModelCheckpoint(
        filepath=str(CHECKPOINTS_DIR / f'{model_name}_best.keras'),
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
    
    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    )
    
    csv_logger = CSVLogger(
        filename=str(LOGS_DIR / f'{model_name}_training.log')
    )
    
    return [checkpoint, early_stop, reduce_lr, csv_logger]

print("Callbacks configured")
# Out:
# Callbacks configured

# %% [markdown]
# ## 7. Trenowanie modeli CNN

# %%
# Trenowanie baseline CNN bez augmentacji
if TRAIN_DIR.exists() and VALID_DIR.exists():
    print("Training baseline CNN without augmentation...")
    
    history_baseline = model_baseline.fit(
        train_generator_baseline,
        epochs=EPOCHS,
        validation_data=valid_generator,
        callbacks=get_callbacks('cnn_baseline'),
        verbose=1
    )
    
    # Zapisz ostatni model
    model_baseline.save(CHECKPOINTS_DIR / 'cnn_baseline_final.keras')
    print(f"\nBaseline model saved to {CHECKPOINTS_DIR / 'cnn_baseline_final.keras'}")
# Out:
# Training baseline CNN without augmentation...
# Epoch 1/50
# I0000 00:00:1775214151.344818     591 generator_dataset_op.cc:213] Memory patch applied: M_TRIM_THRESHOLD=128 kb was set.
# I0000 00:00:1775214153.075639     759 service.cc:153] XLA service 0x78be5c003f40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775214153.075691     759 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 4060, Compute Capability 8.9 (Driver: 13.2.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.20.0)
# I0000 00:00:1775214153.153304     759 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1775214153.510261     759 cuda_dnn.cc:461] Loaded cuDNN version 92000
# I0000 00:00:1775214153.581736     759 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_2461__.44
#   1/239 ━━━━━━━━━━━━━━━━━━━━ 56:16 14s/step - accuracy: 0.1250 - loss: 3.9386
# I0000 00:00:1775214165.326061     759 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1775214165.854644     756 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_2461__.44
# I0000 00:00:1775214167.242568     756 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1775214168.452790    1072 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_10', 292 bytes spill stores, 304 bytes spill loads
#
# I0000 00:00:1775214171.391605     756 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1775214172.934334    1078 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_6', 72 bytes spill stores, 72 bytes spill loads
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.1344 - loss: 3.7864
# I0000 00:00:1775214208.188299     759 dot_search_space.cc:240] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# I0000 00:00:1775214209.775495    1358 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_6', 296 bytes spill stores, 308 bytes spill loads
# Epoch 1: val_accuracy improved from None to 0.55094, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_baseline_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 65s 213ms/step - accuracy: 0.2341 - loss: 3.0692 - val_accuracy: 0.5509 - val_loss: 1.6043 - learning_rate: 0.0010
# Epoch 2/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.4710 - loss: 1.9755
# Epoch 2: val_accuracy improved from 0.55094 to 0.65660, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_baseline_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 26s 107ms/step - accuracy: 0.4889 - loss: 1.9159 - val_accuracy: 0.6566 - val_loss: 1.2331 - learning_rate: 0.0010
# Epoch 3/50
# 238/239 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6311 - loss: 1.3608
# Epoch 3: val_accuracy improved from 0.65660 to 0.73585, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_baseline_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 23s 96ms/step - accuracy: 0.6368 - loss: 1.3288 - val_accuracy: 0.7358 - val_loss: 0.9055 - learning_rate: 0.0010
# Epoch 4/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7524 - loss: 0.8912
# Epoch 4: val_accuracy improved from 0.73585 to 0.77358, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_baseline_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 22s 94ms/step - accuracy: 0.7491 - loss: 0.9009 - val_accuracy: 0.7736 - val_loss: 0.8779 - learning_rate: 0.0010
# Epoch 5/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8306 - loss: 0.6085
# Epoch 5: val_accuracy improved from 0.77358 to 0.79245, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_baseline_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 26s 109ms/step - accuracy: 0.8238 - loss: 0.6224 - val_accuracy: 0.7925 - val_loss: 0.8199 - learning_rate: 0.0010
# Epoch 6/50
# 238/239 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8750 - loss: 0.4464
# Epoch 6: val_accuracy improved from 0.79245 to 0.82642, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_baseline_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 17s 71ms/step - accuracy: 0.8674 - loss: 0.4734 - val_accuracy: 0.8264 - val_loss: 0.7433 - learning_rate: 0.0010
# Epoch 7/50
# 238/239 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9048 - loss: 0.3361
# Epoch 7: val_accuracy did not improve from 0.82642
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 16s 68ms/step - accuracy: 0.8995 - loss: 0.3529 - val_accuracy: 0.8113 - val_loss: 0.7185 - learning_rate: 0.0010
# Epoch 8/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9230 - loss: 0.2796
# Epoch 8: val_accuracy did not improve from 0.82642
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 15s 64ms/step - accuracy: 0.9171 - loss: 0.2922 - val_accuracy: 0.8226 - val_loss: 0.8800 - learning_rate: 0.0010
# Epoch 9/50
# 238/239 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9283 - loss: 0.2375
# Epoch 9: val_accuracy did not improve from 0.82642
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 23s 96ms/step - accuracy: 0.9330 - loss: 0.2347 - val_accuracy: 0.8075 - val_loss: 0.9315 - learning_rate: 0.0010
# Epoch 10/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9393 - loss: 0.2029
# Epoch 10: val_accuracy did not improve from 0.82642
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 22s 94ms/step - accuracy: 0.9403 - loss: 0.1995 - val_accuracy: 0.8000 - val_loss: 1.0161 - learning_rate: 0.0010
# Epoch 11/50
# 238/239 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9533 - loss: 0.1575
# Epoch 11: val_accuracy did not improve from 0.82642
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.9479 - loss: 0.1785 - val_accuracy: 0.8151 - val_loss: 0.8430 - learning_rate: 0.0010
# Epoch 12/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9594 - loss: 0.1446
# Epoch 12: val_accuracy did not improve from 0.82642
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 24s 99ms/step - accuracy: 0.9565 - loss: 0.1511 - val_accuracy: 0.7962 - val_loss: 0.9843 - learning_rate: 0.0010
# Epoch 13/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9685 - loss: 0.1151
# Epoch 13: val_accuracy did not improve from 0.82642
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 21s 87ms/step - accuracy: 0.9696 - loss: 0.1088 - val_accuracy: 0.8189 - val_loss: 0.9313 - learning_rate: 5.0000e-04
# Epoch 14/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9779 - loss: 0.0775
# Epoch 14: val_accuracy did not improve from 0.82642
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 22s 94ms/step - accuracy: 0.9788 - loss: 0.0773 - val_accuracy: 0.8151 - val_loss: 0.9726 - learning_rate: 5.0000e-04
# Epoch 15/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9783 - loss: 0.0786
# Epoch 15: val_accuracy improved from 0.82642 to 0.83019, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_baseline_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 23s 95ms/step - accuracy: 0.9793 - loss: 0.0733 - val_accuracy: 0.8302 - val_loss: 1.0504 - learning_rate: 5.0000e-04
# Epoch 16/50
# 238/239 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9810 - loss: 0.0654
# Epoch 16: val_accuracy did not improve from 0.83019
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.9802 - loss: 0.0644 - val_accuracy: 0.8302 - val_loss: 1.0371 - learning_rate: 5.0000e-04
# Epoch 17/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9866 - loss: 0.0525
# Epoch 17: val_accuracy did not improve from 0.83019
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 20s 84ms/step - accuracy: 0.9831 - loss: 0.0591 - val_accuracy: 0.8226 - val_loss: 1.1065 - learning_rate: 5.0000e-04
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
#
# Baseline model saved to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_baseline_final.keras

# %%
# Trenowanie zoptymalizowanego CNN z augmentacja
if TRAIN_DIR.exists() and VALID_DIR.exists():
    print("Training optimized CNN with augmentation...")
    
    history_optimized = model_optimized.fit(
        train_generator_augmented,
        epochs=EPOCHS,
        validation_data=valid_generator,
        callbacks=get_callbacks('cnn_optimized'),
        verbose=1
    )
    
    # Zapisz ostatni model
    model_optimized.save(CHECKPOINTS_DIR / 'cnn_optimized_final.keras')
    print(f"\nOptimized model saved to {CHECKPOINTS_DIR / 'cnn_optimized_final.keras'}")
# Out:
# Training optimized CNN with augmentation...
# Epoch 1/50
# I0000 00:00:1775214567.807797     758 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_27849__.107
# 149/239 ━━━━━━━━━━━━━━━━━━━━ 28s 313ms/step - accuracy: 0.0312 - loss: 4.9100
# I0000 00:00:1775214642.287929     759 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_27849__.107
# I0000 00:00:1775214643.256147    3237 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_6', 8 bytes spill stores, 8 bytes spill loads
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.0376 - loss: 4.7565
# Epoch 1: val_accuracy improved from None to 0.02642, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 145s 471ms/step - accuracy: 0.0559 - loss: 4.3807 - val_accuracy: 0.0264 - val_loss: 6.0905 - learning_rate: 0.0010
# Epoch 2/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.0975 - loss: 3.6769
# Epoch 2: val_accuracy improved from 0.02642 to 0.24906, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 86s 360ms/step - accuracy: 0.1124 - loss: 3.5162 - val_accuracy: 0.2491 - val_loss: 2.4652 - learning_rate: 0.0010
# Epoch 3/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.1511 - loss: 3.2210
# Epoch 3: val_accuracy improved from 0.24906 to 0.29434, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 95s 396ms/step - accuracy: 0.1584 - loss: 3.1576 - val_accuracy: 0.2943 - val_loss: 2.3287 - learning_rate: 0.0010
# Epoch 4/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.1782 - loss: 2.9424
# Epoch 4: val_accuracy did not improve from 0.29434
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 81s 337ms/step - accuracy: 0.1780 - loss: 2.9443 - val_accuracy: 0.2113 - val_loss: 2.7437 - learning_rate: 0.0010
# Epoch 5/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.2010 - loss: 2.8115
# Epoch 5: val_accuracy did not improve from 0.29434
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 89s 373ms/step - accuracy: 0.2049 - loss: 2.7965 - val_accuracy: 0.2755 - val_loss: 2.5405 - learning_rate: 0.0010
# Epoch 6/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.2099 - loss: 2.6732
# Epoch 6: val_accuracy improved from 0.29434 to 0.35849, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 96s 399ms/step - accuracy: 0.2131 - loss: 2.6791 - val_accuracy: 0.3585 - val_loss: 1.9591 - learning_rate: 0.0010
# Epoch 7/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.2506 - loss: 2.5869
# Epoch 7: val_accuracy improved from 0.35849 to 0.36226, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 89s 370ms/step - accuracy: 0.2465 - loss: 2.5775 - val_accuracy: 0.3623 - val_loss: 2.0073 - learning_rate: 0.0010
# Epoch 8/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.2793 - loss: 2.4740
# Epoch 8: val_accuracy improved from 0.36226 to 0.40755, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 321ms/step - accuracy: 0.2812 - loss: 2.4681 - val_accuracy: 0.4075 - val_loss: 2.0387 - learning_rate: 0.0010
# Epoch 9/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.3142 - loss: 2.3477
# Epoch 9: val_accuracy improved from 0.40755 to 0.50566, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 95s 397ms/step - accuracy: 0.3170 - loss: 2.3439 - val_accuracy: 0.5057 - val_loss: 1.5781 - learning_rate: 0.0010
# Epoch 10/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.3414 - loss: 2.2569
# Epoch 10: val_accuracy improved from 0.50566 to 0.51321, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 96s 399ms/step - accuracy: 0.3389 - loss: 2.2725 - val_accuracy: 0.5132 - val_loss: 1.7401 - learning_rate: 0.0010
# Epoch 11/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.3576 - loss: 2.1803
# Epoch 11: val_accuracy improved from 0.51321 to 0.59623, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 352ms/step - accuracy: 0.3582 - loss: 2.1802 - val_accuracy: 0.5962 - val_loss: 1.3363 - learning_rate: 0.0010
# Epoch 12/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.4014 - loss: 2.0710
# Epoch 12: val_accuracy did not improve from 0.59623
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 312ms/step - accuracy: 0.4153 - loss: 2.0430 - val_accuracy: 0.4566 - val_loss: 1.8196 - learning_rate: 0.0010
# Epoch 13/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.4323 - loss: 1.9421
# Epoch 13: val_accuracy improved from 0.59623 to 0.65283, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 89s 374ms/step - accuracy: 0.4342 - loss: 1.9448 - val_accuracy: 0.6528 - val_loss: 1.1901 - learning_rate: 0.0010
# Epoch 14/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.4691 - loss: 1.8303
# Epoch 14: val_accuracy did not improve from 0.65283
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 92s 383ms/step - accuracy: 0.4534 - loss: 1.8758 - val_accuracy: 0.6340 - val_loss: 1.1784 - learning_rate: 0.0010
# Epoch 15/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.4726 - loss: 1.7905
# Epoch 15: val_accuracy improved from 0.65283 to 0.70189, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 80s 336ms/step - accuracy: 0.4770 - loss: 1.7812 - val_accuracy: 0.7019 - val_loss: 1.0048 - learning_rate: 0.0010
# Epoch 16/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.4981 - loss: 1.7143
# Epoch 16: val_accuracy did not improve from 0.70189
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 87s 364ms/step - accuracy: 0.5005 - loss: 1.7108 - val_accuracy: 0.6491 - val_loss: 1.0449 - learning_rate: 0.0010
# Epoch 17/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5098 - loss: 1.6421
# Epoch 17: val_accuracy did not improve from 0.70189
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 90s 375ms/step - accuracy: 0.5004 - loss: 1.6890 - val_accuracy: 0.4566 - val_loss: 1.8347 - learning_rate: 0.0010
# Epoch 18/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.5147 - loss: 1.6801
# Epoch 18: val_accuracy improved from 0.70189 to 0.70566, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 96s 403ms/step - accuracy: 0.5266 - loss: 1.6459 - val_accuracy: 0.7057 - val_loss: 0.9527 - learning_rate: 0.0010
# Epoch 19/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.5420 - loss: 1.5658
# Epoch 19: val_accuracy improved from 0.70566 to 0.73208, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 320ms/step - accuracy: 0.5375 - loss: 1.5835 - val_accuracy: 0.7321 - val_loss: 0.9155 - learning_rate: 0.0010
# Epoch 20/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.5539 - loss: 1.5292
# Epoch 20: val_accuracy did not improve from 0.73208
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 88s 368ms/step - accuracy: 0.5458 - loss: 1.5511 - val_accuracy: 0.6415 - val_loss: 1.1322 - learning_rate: 0.0010
# Epoch 21/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.5440 - loss: 1.5489
# Epoch 21: val_accuracy did not improve from 0.73208
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 153s 394ms/step - accuracy: 0.5529 - loss: 1.5213 - val_accuracy: 0.6981 - val_loss: 0.9505 - learning_rate: 0.0010
# Epoch 22/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.5638 - loss: 1.4766
# Epoch 22: val_accuracy improved from 0.73208 to 0.76226, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 88s 368ms/step - accuracy: 0.5678 - loss: 1.4659 - val_accuracy: 0.7623 - val_loss: 0.7954 - learning_rate: 0.0010
# Epoch 23/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.5821 - loss: 1.3816
# Epoch 23: val_accuracy did not improve from 0.76226
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 313ms/step - accuracy: 0.5847 - loss: 1.3978 - val_accuracy: 0.7623 - val_loss: 0.7918 - learning_rate: 0.0010
# Epoch 24/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.6088 - loss: 1.3548
# Epoch 24: val_accuracy did not improve from 0.76226
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 76s 316ms/step - accuracy: 0.5922 - loss: 1.4087 - val_accuracy: 0.7547 - val_loss: 0.7639 - learning_rate: 0.0010
# Epoch 25/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5998 - loss: 1.3591
# Epoch 25: val_accuracy improved from 0.76226 to 0.79245, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 92s 385ms/step - accuracy: 0.6014 - loss: 1.3580 - val_accuracy: 0.7925 - val_loss: 0.6651 - learning_rate: 0.0010
# Epoch 26/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.6114 - loss: 1.3102
# Epoch 26: val_accuracy did not improve from 0.79245
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 94s 393ms/step - accuracy: 0.6102 - loss: 1.3229 - val_accuracy: 0.7887 - val_loss: 0.6647 - learning_rate: 0.0010
# Epoch 27/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.6316 - loss: 1.2509
# Epoch 27: val_accuracy improved from 0.79245 to 0.81132, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 90s 375ms/step - accuracy: 0.6270 - loss: 1.2716 - val_accuracy: 0.8113 - val_loss: 0.6359 - learning_rate: 0.0010
# Epoch 28/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.6287 - loss: 1.2501
# Epoch 28: val_accuracy improved from 0.81132 to 0.81509, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 331ms/step - accuracy: 0.6304 - loss: 1.2478 - val_accuracy: 0.8151 - val_loss: 0.5864 - learning_rate: 0.0010
# Epoch 29/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.6381 - loss: 1.2095
# Epoch 29: val_accuracy did not improve from 0.81509
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 90s 374ms/step - accuracy: 0.6442 - loss: 1.2107 - val_accuracy: 0.8038 - val_loss: 0.7054 - learning_rate: 0.0010
# Epoch 30/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.6620 - loss: 1.1625
# Epoch 30: val_accuracy improved from 0.81509 to 0.82642, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 78s 326ms/step - accuracy: 0.6531 - loss: 1.1895 - val_accuracy: 0.8264 - val_loss: 0.5462 - learning_rate: 0.0010
# Epoch 31/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.6595 - loss: 1.1679
# Epoch 31: val_accuracy improved from 0.82642 to 0.83396, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 95s 395ms/step - accuracy: 0.6565 - loss: 1.1787 - val_accuracy: 0.8340 - val_loss: 0.6444 - learning_rate: 0.0010
# Epoch 32/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.6662 - loss: 1.1471
# Epoch 32: val_accuracy improved from 0.83396 to 0.85283, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 97s 406ms/step - accuracy: 0.6675 - loss: 1.1526 - val_accuracy: 0.8528 - val_loss: 0.5421 - learning_rate: 0.0010
# Epoch 33/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.6662 - loss: 1.0966
# Epoch 33: val_accuracy did not improve from 0.85283
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 320ms/step - accuracy: 0.6616 - loss: 1.1286 - val_accuracy: 0.8528 - val_loss: 0.5376 - learning_rate: 0.0010
# Epoch 34/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.6835 - loss: 1.1063
# Epoch 34: val_accuracy improved from 0.85283 to 0.87925, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 328ms/step - accuracy: 0.6788 - loss: 1.1148 - val_accuracy: 0.8792 - val_loss: 0.4058 - learning_rate: 0.0010
# Epoch 35/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.6927 - loss: 1.0525
# Epoch 35: val_accuracy did not improve from 0.87925
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 312ms/step - accuracy: 0.6827 - loss: 1.0781 - val_accuracy: 0.8792 - val_loss: 0.4944 - learning_rate: 0.0010
# Epoch 36/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.6927 - loss: 1.0473
# Epoch 36: val_accuracy did not improve from 0.87925
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 85s 357ms/step - accuracy: 0.6885 - loss: 1.0687 - val_accuracy: 0.8679 - val_loss: 0.4822 - learning_rate: 0.0010
# Epoch 37/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.6830 - loss: 1.0700
# Epoch 37: val_accuracy did not improve from 0.87925
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 323ms/step - accuracy: 0.6752 - loss: 1.1025 - val_accuracy: 0.8717 - val_loss: 0.4567 - learning_rate: 0.0010
# Epoch 38/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.6957 - loss: 1.0532
# Epoch 38: val_accuracy did not improve from 0.87925
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 80s 333ms/step - accuracy: 0.6960 - loss: 1.0375 - val_accuracy: 0.8755 - val_loss: 0.4734 - learning_rate: 0.0010
# Epoch 39/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.7224 - loss: 0.9368
# Epoch 39: val_accuracy did not improve from 0.87925
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 89s 373ms/step - accuracy: 0.7173 - loss: 0.9672 - val_accuracy: 0.8491 - val_loss: 0.5323 - learning_rate: 0.0010
# Epoch 40/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.7211 - loss: 0.9612
# Epoch 40: val_accuracy improved from 0.87925 to 0.88302, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 94s 392ms/step - accuracy: 0.7289 - loss: 0.9317 - val_accuracy: 0.8830 - val_loss: 0.3609 - learning_rate: 5.0000e-04
# Epoch 41/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.7308 - loss: 0.9094
# Epoch 41: val_accuracy improved from 0.88302 to 0.89057, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 78s 327ms/step - accuracy: 0.7360 - loss: 0.9030 - val_accuracy: 0.8906 - val_loss: 0.3749 - learning_rate: 5.0000e-04
# Epoch 42/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.7299 - loss: 0.8926
# Epoch 42: val_accuracy improved from 0.89057 to 0.90566, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 97s 404ms/step - accuracy: 0.7322 - loss: 0.8827 - val_accuracy: 0.9057 - val_loss: 0.3482 - learning_rate: 5.0000e-04
# Epoch 43/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.7431 - loss: 0.8536
# Epoch 43: val_accuracy did not improve from 0.90566
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 93s 386ms/step - accuracy: 0.7444 - loss: 0.8489 - val_accuracy: 0.8830 - val_loss: 0.4312 - learning_rate: 5.0000e-04
# Epoch 44/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7625 - loss: 0.8236
# Epoch 44: val_accuracy did not improve from 0.90566
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 78s 326ms/step - accuracy: 0.7554 - loss: 0.8391 - val_accuracy: 0.8981 - val_loss: 0.3192 - learning_rate: 5.0000e-04
# Epoch 45/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.7669 - loss: 0.8028
# Epoch 45: val_accuracy improved from 0.90566 to 0.91698, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 80s 334ms/step - accuracy: 0.7591 - loss: 0.8161 - val_accuracy: 0.9170 - val_loss: 0.2955 - learning_rate: 5.0000e-04
# Epoch 46/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.7595 - loss: 0.8162
# Epoch 46: val_accuracy did not improve from 0.91698
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 91s 380ms/step - accuracy: 0.7577 - loss: 0.8252 - val_accuracy: 0.8981 - val_loss: 0.3455 - learning_rate: 5.0000e-04
# Epoch 47/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7662 - loss: 0.7768
# Epoch 47: val_accuracy did not improve from 0.91698
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 87s 362ms/step - accuracy: 0.7652 - loss: 0.7877 - val_accuracy: 0.9132 - val_loss: 0.3262 - learning_rate: 5.0000e-04
# Epoch 48/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.7627 - loss: 0.7858
# Epoch 48: val_accuracy improved from 0.91698 to 0.92453, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 89s 372ms/step - accuracy: 0.7606 - loss: 0.7922 - val_accuracy: 0.9245 - val_loss: 0.2803 - learning_rate: 5.0000e-04
# Epoch 49/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.7725 - loss: 0.7736
# Epoch 49: val_accuracy did not improve from 0.92453
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 94s 390ms/step - accuracy: 0.7723 - loss: 0.7798 - val_accuracy: 0.9208 - val_loss: 0.2778 - learning_rate: 5.0000e-04
# Epoch 50/50
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.7689 - loss: 0.7619
# Epoch 50: val_accuracy did not improve from 0.92453
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 94s 392ms/step - accuracy: 0.7689 - loss: 0.7641 - val_accuracy: 0.9245 - val_loss: 0.2724 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 50.
#
# Optimized model saved to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/cnn_optimized_final.keras

# %% [markdown]
# ## 8. Wizualizacja wynikow treningu CNN

# %%
def plot_training_history(histories, model_names, save_name):
    """Wizualizacja historii treningu"""
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 5))
    
    # Accuracy
    for history, name in zip(histories, model_names):
        axes[0].plot(history.history['accuracy'], label=f'{name} train', linewidth=2)
        axes[0].plot(history.history['val_accuracy'], label=f'{name} val', linestyle='--', linewidth=2)
    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('accuracy')
    axes[0].set_title('model accuracy')
    axes[0].legend(loc='lower right')
    axes[0].grid(True, alpha=0.3)
    
    # Loss
    for history, name in zip(histories, model_names):
        axes[1].plot(history.history['loss'], label=f'{name} train', linewidth=2)
        axes[1].plot(history.history['val_loss'], label=f'{name} val', linestyle='--', linewidth=2)
    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('loss')
    axes[1].set_title('model loss')
    axes[1].legend(loc='upper right')
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / f'{save_name}.png', dpi=150, bbox_inches='tight')
    plt.show()

if 'history_baseline' in locals() and 'history_optimized' in locals():
    plot_training_history(
        [history_baseline, history_optimized],
        ['baseline', 'optimized'],
        'cnn_training_comparison'
    )

# %% [markdown]
# ## 9. Transfer Learning - modele pretrenowane

# %%
def create_transfer_model(base_model_name, num_classes, trainable_layers=0):
    """Utworz model transfer learning"""
    
    # Wybor bazowego modelu
    base_models = {
        'VGG16': VGG16,
        'VGG19': VGG19,
        'ResNet50': ResNet50,
        'InceptionV3': InceptionV3,
        'MobileNetV2': MobileNetV2,
        'EfficientNetB0': EfficientNetB0
    }
    
    base_model_class = base_models[base_model_name]
    base_model = base_model_class(
        weights='imagenet',
        include_top=False,
        input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
    )
    
    # Zamroz warstwy bazowe
    base_model.trainable = False
    
    # Opcjonalnie odmroz ostatnie warstwy
    if trainable_layers > 0:
        base_model.trainable = True
        for layer in base_model.layers[:-trainable_layers]:
            layer.trainable = False
    
    # Utworz kompletny model
    inputs = Input(shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs, name=base_model_name)
    
    return model

print("Transfer learning model builder ready")
# Out:
# Transfer learning model builder ready

# %%
# Utworz modele transfer learning
transfer_models = {}
model_architectures = ['VGG16', 'ResNet50', 'MobileNetV2', 'EfficientNetB0']

for arch in model_architectures:
    print(f"\nCreating {arch} model...")
    model = create_transfer_model(arch, NUM_CLASSES)
    
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    transfer_models[arch] = model
    
    print(f"{arch} - Total params: {model.count_params():,}")
    trainable_params = sum([tf.size(w).numpy() for w in model.trainable_weights])
    print(f"{arch} - Trainable params: {trainable_params:,}")
# Out:
# Creating VGG16 model...
# VGG16 - Total params: 15,125,365
# VGG16 - Trainable params: 409,141
#
# Creating ResNet50 model...
# ResNet50 - Total params: 24,784,821
# ResNet50 - Trainable params: 1,195,573
#
# Creating MobileNetV2 model...
# MobileNetV2 - Total params: 3,061,877
# MobileNetV2 - Trainable params: 802,357
#
# Creating EfficientNetB0 model...
# EfficientNetB0 - Total params: 4,853,464
# EfficientNetB0 - Trainable params: 802,357

# %% [markdown]
# ## 10. Trenowanie modeli transfer learning

# %%
# Trenuj wszystkie modele transfer learning
transfer_histories = {}
transfer_epochs = 30  # mniej epok dla transfer learning

if TRAIN_DIR.exists() and VALID_DIR.exists():
    for model_name, model in transfer_models.items():
        print(f"\n{'='*60}")
        print(f"Training {model_name}...")
        print('='*60)
        
        history = model.fit(
            train_generator_augmented,
            epochs=transfer_epochs,
            validation_data=valid_generator,
            callbacks=get_callbacks(f'transfer_{model_name}'),
            verbose=1
        )
        
        transfer_histories[model_name] = history
        
        # Zapisz ostatni model
        model.save(CHECKPOINTS_DIR / f'transfer_{model_name}_final.keras')
        print(f"Model saved to {CHECKPOINTS_DIR / f'transfer_{model_name}_final.keras'}")
else:
    print("Data directories not found. Skipping transfer learning training.")
# Out:
# ============================================================
# Training VGG16...
# ============================================================
# Epoch 1/30
# I0000 00:00:1775219027.415640     756 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_100994__.85
#  47/239 ━━━━━━━━━━━━━━━━━━━━ 56s 295ms/step - accuracy: 0.0613 - loss: 4.7514
# I0000 00:00:1775219055.012790     759 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_100994__.85
# I0000 00:00:1775219056.696826    8208 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_10', 8 bytes spill stores, 8 bytes spill loads
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.1037 - loss: 4.0660
# Epoch 1: val_accuracy improved from None to 0.26415, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 106s 377ms/step - accuracy: 0.1415 - loss: 3.5915 - val_accuracy: 0.2642 - val_loss: 2.5645 - learning_rate: 0.0010
# Epoch 2/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.2311 - loss: 2.8173
# Epoch 2: val_accuracy improved from 0.26415 to 0.39245, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 86s 358ms/step - accuracy: 0.2417 - loss: 2.7498 - val_accuracy: 0.3925 - val_loss: 1.8607 - learning_rate: 0.0010
# Epoch 3/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.2914 - loss: 2.4797
# Epoch 3: val_accuracy improved from 0.39245 to 0.43019, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 94s 394ms/step - accuracy: 0.2960 - loss: 2.4653 - val_accuracy: 0.4302 - val_loss: 1.6561 - learning_rate: 0.0010
# Epoch 4/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.3228 - loss: 2.2881
# Epoch 4: val_accuracy improved from 0.43019 to 0.46792, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 85s 357ms/step - accuracy: 0.3322 - loss: 2.2781 - val_accuracy: 0.4679 - val_loss: 1.6178 - learning_rate: 0.0010
# Epoch 5/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.3599 - loss: 2.1627
# Epoch 5: val_accuracy improved from 0.46792 to 0.47547, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 87s 365ms/step - accuracy: 0.3701 - loss: 2.1429 - val_accuracy: 0.4755 - val_loss: 1.5691 - learning_rate: 0.0010
# Epoch 6/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.3805 - loss: 2.0887
# Epoch 6: val_accuracy improved from 0.47547 to 0.55472, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 76s 316ms/step - accuracy: 0.3873 - loss: 2.0885 - val_accuracy: 0.5547 - val_loss: 1.3579 - learning_rate: 0.0010
# Epoch 7/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4036 - loss: 2.0259
# Epoch 7: val_accuracy improved from 0.55472 to 0.59245, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 352ms/step - accuracy: 0.4116 - loss: 1.9928 - val_accuracy: 0.5925 - val_loss: 1.3458 - learning_rate: 0.0010
# Epoch 8/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.4218 - loss: 1.9314
# Epoch 8: val_accuracy improved from 0.59245 to 0.62642, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 89s 371ms/step - accuracy: 0.4267 - loss: 1.9423 - val_accuracy: 0.6264 - val_loss: 1.2446 - learning_rate: 0.0010
# Epoch 9/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.4459 - loss: 1.8595
# Epoch 9: val_accuracy did not improve from 0.62642
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 92s 386ms/step - accuracy: 0.4380 - loss: 1.8949 - val_accuracy: 0.6226 - val_loss: 1.2735 - learning_rate: 0.0010
# Epoch 10/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.4437 - loss: 1.8525
# Epoch 10: val_accuracy did not improve from 0.62642
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 87s 362ms/step - accuracy: 0.4448 - loss: 1.8649 - val_accuracy: 0.5472 - val_loss: 1.4308 - learning_rate: 0.0010
# Epoch 11/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.4743 - loss: 1.8012
# Epoch 11: val_accuracy improved from 0.62642 to 0.63774, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 315ms/step - accuracy: 0.4664 - loss: 1.8240 - val_accuracy: 0.6377 - val_loss: 1.1854 - learning_rate: 0.0010
# Epoch 12/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.4624 - loss: 1.7997
# Epoch 12: val_accuracy did not improve from 0.63774
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 323ms/step - accuracy: 0.4654 - loss: 1.7997 - val_accuracy: 0.6075 - val_loss: 1.1865 - learning_rate: 0.0010
# Epoch 13/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.4812 - loss: 1.7620
# Epoch 13: val_accuracy did not improve from 0.63774
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 89s 371ms/step - accuracy: 0.4765 - loss: 1.7721 - val_accuracy: 0.6113 - val_loss: 1.2007 - learning_rate: 0.0010
# Epoch 14/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.5006 - loss: 1.7193
# Epoch 14: val_accuracy improved from 0.63774 to 0.64151, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 83s 347ms/step - accuracy: 0.4916 - loss: 1.7375 - val_accuracy: 0.6415 - val_loss: 1.1237 - learning_rate: 0.0010
# Epoch 15/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.4915 - loss: 1.7218
# Epoch 15: val_accuracy did not improve from 0.64151
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 83s 346ms/step - accuracy: 0.4806 - loss: 1.7574 - val_accuracy: 0.6151 - val_loss: 1.2055 - learning_rate: 0.0010
# Epoch 16/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.4906 - loss: 1.7104
# Epoch 16: val_accuracy did not improve from 0.64151
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 74s 310ms/step - accuracy: 0.4890 - loss: 1.7107 - val_accuracy: 0.6038 - val_loss: 1.2241 - learning_rate: 0.0010
# Epoch 17/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5100 - loss: 1.6697
# Epoch 17: val_accuracy improved from 0.64151 to 0.66415, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 81s 339ms/step - accuracy: 0.4944 - loss: 1.7091 - val_accuracy: 0.6642 - val_loss: 1.1460 - learning_rate: 0.0010
# Epoch 18/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.5036 - loss: 1.6993
# Epoch 18: val_accuracy did not improve from 0.66415
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 89s 372ms/step - accuracy: 0.4963 - loss: 1.7057 - val_accuracy: 0.6340 - val_loss: 1.1321 - learning_rate: 0.0010
# Epoch 19/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.5066 - loss: 1.6910
# Epoch 19: val_accuracy did not improve from 0.66415
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 90s 377ms/step - accuracy: 0.5022 - loss: 1.7023 - val_accuracy: 0.6340 - val_loss: 1.2812 - learning_rate: 0.0010
# Epoch 20/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.5385 - loss: 1.5777
# Epoch 20: val_accuracy did not improve from 0.66415
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 350ms/step - accuracy: 0.5282 - loss: 1.6059 - val_accuracy: 0.6415 - val_loss: 1.1073 - learning_rate: 5.0000e-04
# Epoch 21/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.5293 - loss: 1.5681
# Epoch 21: val_accuracy did not improve from 0.66415
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 76s 315ms/step - accuracy: 0.5279 - loss: 1.5843 - val_accuracy: 0.6642 - val_loss: 1.0617 - learning_rate: 5.0000e-04
# Epoch 22/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.5341 - loss: 1.5897
# Epoch 22: val_accuracy did not improve from 0.66415
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 87s 364ms/step - accuracy: 0.5266 - loss: 1.5952 - val_accuracy: 0.6415 - val_loss: 1.1227 - learning_rate: 5.0000e-04
# Epoch 23/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5402 - loss: 1.5671
# Epoch 23: val_accuracy did not improve from 0.66415
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 90s 375ms/step - accuracy: 0.5375 - loss: 1.5628 - val_accuracy: 0.6113 - val_loss: 1.1005 - learning_rate: 5.0000e-04
# Epoch 24/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5434 - loss: 1.5399
# Epoch 24: val_accuracy improved from 0.66415 to 0.66792, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 353ms/step - accuracy: 0.5428 - loss: 1.5345 - val_accuracy: 0.6679 - val_loss: 1.0676 - learning_rate: 5.0000e-04
# Epoch 25/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.5547 - loss: 1.5203
# Epoch 25: val_accuracy did not improve from 0.66792
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 82s 344ms/step - accuracy: 0.5464 - loss: 1.5461 - val_accuracy: 0.6377 - val_loss: 1.0834 - learning_rate: 5.0000e-04
# Epoch 26/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5448 - loss: 1.5278
# Epoch 26: val_accuracy did not improve from 0.66792
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 351ms/step - accuracy: 0.5411 - loss: 1.5549 - val_accuracy: 0.6415 - val_loss: 1.0806 - learning_rate: 5.0000e-04
# Epoch 27/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5563 - loss: 1.5084
# Epoch 27: val_accuracy did not improve from 0.66792
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 80s 336ms/step - accuracy: 0.5550 - loss: 1.5110 - val_accuracy: 0.6642 - val_loss: 1.0656 - learning_rate: 2.5000e-04
# Epoch 28/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.5582 - loss: 1.4804
# Epoch 28: val_accuracy did not improve from 0.66792
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 93s 388ms/step - accuracy: 0.5664 - loss: 1.4701 - val_accuracy: 0.6642 - val_loss: 1.0441 - learning_rate: 2.5000e-04
# Epoch 29/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5693 - loss: 1.4490
# Epoch 29: val_accuracy improved from 0.66792 to 0.67547, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 349ms/step - accuracy: 0.5578 - loss: 1.4735 - val_accuracy: 0.6755 - val_loss: 1.0278 - learning_rate: 2.5000e-04
# Epoch 30/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.5524 - loss: 1.4899
# Epoch 30: val_accuracy did not improve from 0.67547
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 94s 394ms/step - accuracy: 0.5561 - loss: 1.4735 - val_accuracy: 0.6717 - val_loss: 1.0552 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 29.
# Model saved to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_VGG16_final.keras
#
# ============================================================
# Training ResNet50...
# ============================================================
# Epoch 1/30
# I0000 00:00:1775221601.130234     757 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_145090__.200
# 118/239 ━━━━━━━━━━━━━━━━━━━━ 45s 379ms/step - accuracy: 0.0368 - loss: 4.8203
# I0000 00:00:1775221659.483245     759 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_145090__.200
# I0000 00:00:1775221659.902046   11184 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_10', 8 bytes spill stores, 8 bytes spill loads
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.0487 - loss: 4.5882
# Epoch 1: val_accuracy improved from None to 0.13208, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 139s 494ms/step - accuracy: 0.0658 - loss: 4.2400 - val_accuracy: 0.1321 - val_loss: 3.3814 - learning_rate: 0.0010
# Epoch 2/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.1059 - loss: 3.7145
# Epoch 2: val_accuracy improved from 0.13208 to 0.16604, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 97s 407ms/step - accuracy: 0.1120 - loss: 3.6059 - val_accuracy: 0.1660 - val_loss: 2.9238 - learning_rate: 0.0010
# Epoch 3/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.1350 - loss: 3.3539
# Epoch 3: val_accuracy improved from 0.16604 to 0.23396, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 321ms/step - accuracy: 0.1367 - loss: 3.3308 - val_accuracy: 0.2340 - val_loss: 2.8245 - learning_rate: 0.0010
# Epoch 4/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.1545 - loss: 3.2081
# Epoch 4: val_accuracy improved from 0.23396 to 0.26415, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 321ms/step - accuracy: 0.1584 - loss: 3.1699 - val_accuracy: 0.2642 - val_loss: 2.6479 - learning_rate: 0.0010
# Epoch 5/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.1716 - loss: 3.0817
# Epoch 5: val_accuracy did not improve from 0.26415
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 85s 356ms/step - accuracy: 0.1726 - loss: 3.0577 - val_accuracy: 0.2604 - val_loss: 2.5542 - learning_rate: 0.0010
# Epoch 6/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.1807 - loss: 2.9875
# Epoch 6: val_accuracy improved from 0.26415 to 0.32453, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 91s 379ms/step - accuracy: 0.1851 - loss: 2.9708 - val_accuracy: 0.3245 - val_loss: 2.3035 - learning_rate: 0.0010
# Epoch 7/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.1917 - loss: 2.8947
# Epoch 7: val_accuracy did not improve from 0.32453
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 322ms/step - accuracy: 0.1916 - loss: 2.8998 - val_accuracy: 0.3057 - val_loss: 2.2604 - learning_rate: 0.0010
# Epoch 8/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.2187 - loss: 2.8275
# Epoch 8: val_accuracy improved from 0.32453 to 0.33962, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 350ms/step - accuracy: 0.2185 - loss: 2.8379 - val_accuracy: 0.3396 - val_loss: 2.2204 - learning_rate: 0.0010
# Epoch 9/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.2191 - loss: 2.8173
# Epoch 9: val_accuracy improved from 0.33962 to 0.40000, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 76s 319ms/step - accuracy: 0.2163 - loss: 2.8262 - val_accuracy: 0.4000 - val_loss: 2.1073 - learning_rate: 0.0010
# Epoch 10/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.2211 - loss: 2.8091
# Epoch 10: val_accuracy did not improve from 0.40000
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 83s 349ms/step - accuracy: 0.2240 - loss: 2.7861 - val_accuracy: 0.3472 - val_loss: 2.1238 - learning_rate: 0.0010
# Epoch 11/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.2344 - loss: 2.7522
# Epoch 11: val_accuracy improved from 0.40000 to 0.40377, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 91s 379ms/step - accuracy: 0.2312 - loss: 2.7431 - val_accuracy: 0.4038 - val_loss: 2.0977 - learning_rate: 0.0010
# Epoch 12/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.2434 - loss: 2.7218
# Epoch 12: val_accuracy did not improve from 0.40377
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 88s 367ms/step - accuracy: 0.2497 - loss: 2.7244 - val_accuracy: 0.3925 - val_loss: 2.0556 - learning_rate: 0.0010
# Epoch 13/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.2478 - loss: 2.7035
# Epoch 13: val_accuracy did not improve from 0.40377
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 88s 369ms/step - accuracy: 0.2517 - loss: 2.7041 - val_accuracy: 0.3132 - val_loss: 2.3718 - learning_rate: 0.0010
# Epoch 14/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.2468 - loss: 2.6764
# Epoch 14: val_accuracy improved from 0.40377 to 0.40755, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 97s 406ms/step - accuracy: 0.2522 - loss: 2.6859 - val_accuracy: 0.4075 - val_loss: 2.0996 - learning_rate: 0.0010
# Epoch 15/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.2342 - loss: 2.7148
# Epoch 15: val_accuracy improved from 0.40755 to 0.43774, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 80s 334ms/step - accuracy: 0.2424 - loss: 2.6888 - val_accuracy: 0.4377 - val_loss: 1.9353 - learning_rate: 0.0010
# Epoch 16/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.2647 - loss: 2.6410
# Epoch 16: val_accuracy did not improve from 0.43774
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 98s 408ms/step - accuracy: 0.2593 - loss: 2.6535 - val_accuracy: 0.3208 - val_loss: 2.3189 - learning_rate: 0.0010
# Epoch 17/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.2551 - loss: 2.6501
# Epoch 17: val_accuracy did not improve from 0.43774
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 92s 383ms/step - accuracy: 0.2642 - loss: 2.6384 - val_accuracy: 0.4226 - val_loss: 1.9821 - learning_rate: 0.0010
# Epoch 18/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.2649 - loss: 2.6398
# Epoch 18: val_accuracy did not improve from 0.43774
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 91s 379ms/step - accuracy: 0.2694 - loss: 2.6271 - val_accuracy: 0.4264 - val_loss: 1.9887 - learning_rate: 0.0010
# Epoch 19/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.2519 - loss: 2.6414
# Epoch 19: val_accuracy did not improve from 0.43774
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 88s 370ms/step - accuracy: 0.2585 - loss: 2.6342 - val_accuracy: 0.3849 - val_loss: 1.9536 - learning_rate: 0.0010
# Epoch 20/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.2736 - loss: 2.6054
# Epoch 20: val_accuracy did not improve from 0.43774
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 81s 339ms/step - accuracy: 0.2718 - loss: 2.6060 - val_accuracy: 0.3547 - val_loss: 2.1246 - learning_rate: 0.0010
# Epoch 21/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.2944 - loss: 2.5267
# Epoch 21: val_accuracy did not improve from 0.43774
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 96s 400ms/step - accuracy: 0.2921 - loss: 2.5265 - val_accuracy: 0.4189 - val_loss: 1.9618 - learning_rate: 5.0000e-04
# Epoch 22/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.2989 - loss: 2.5194
# Epoch 22: val_accuracy did not improve from 0.43774
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 78s 328ms/step - accuracy: 0.2960 - loss: 2.5195 - val_accuracy: 0.4340 - val_loss: 1.9030 - learning_rate: 5.0000e-04
# Epoch 23/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.3005 - loss: 2.5218
# Epoch 23: val_accuracy improved from 0.43774 to 0.45660, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 90s 376ms/step - accuracy: 0.2974 - loss: 2.5139 - val_accuracy: 0.4566 - val_loss: 1.8446 - learning_rate: 5.0000e-04
# Epoch 24/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.2995 - loss: 2.5222
# Epoch 24: val_accuracy improved from 0.45660 to 0.49057, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 98s 410ms/step - accuracy: 0.2976 - loss: 2.5165 - val_accuracy: 0.4906 - val_loss: 1.8364 - learning_rate: 5.0000e-04
# Epoch 25/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.3162 - loss: 2.4534
# Epoch 25: val_accuracy did not improve from 0.49057
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 81s 339ms/step - accuracy: 0.3072 - loss: 2.4993 - val_accuracy: 0.4453 - val_loss: 1.8276 - learning_rate: 5.0000e-04
# Epoch 26/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.3017 - loss: 2.4870
# Epoch 26: val_accuracy did not improve from 0.49057
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 100s 417ms/step - accuracy: 0.3002 - loss: 2.4848 - val_accuracy: 0.4528 - val_loss: 1.8336 - learning_rate: 5.0000e-04
# Epoch 27/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.3092 - loss: 2.4807
# Epoch 27: val_accuracy improved from 0.49057 to 0.51698, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 83s 346ms/step - accuracy: 0.3033 - loss: 2.4779 - val_accuracy: 0.5170 - val_loss: 1.7150 - learning_rate: 5.0000e-04
# Epoch 28/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.2998 - loss: 2.4992
# Epoch 28: val_accuracy did not improve from 0.51698
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 322ms/step - accuracy: 0.3057 - loss: 2.4798 - val_accuracy: 0.4792 - val_loss: 1.7782 - learning_rate: 5.0000e-04
# Epoch 29/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.3110 - loss: 2.4673
# Epoch 29: val_accuracy did not improve from 0.51698
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 315ms/step - accuracy: 0.3110 - loss: 2.4551 - val_accuracy: 0.4906 - val_loss: 1.8083 - learning_rate: 5.0000e-04
# Epoch 30/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.3320 - loss: 2.4390
# Epoch 30: val_accuracy did not improve from 0.51698
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 88s 366ms/step - accuracy: 0.3183 - loss: 2.4700 - val_accuracy: 0.3774 - val_loss: 2.1044 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 27.
# Model saved to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_ResNet50_final.keras
#
# ============================================================
# Training MobileNetV2...
# ============================================================
# Epoch 1/30
# I0000 00:00:1775224249.222309     758 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_208685__.137
# E0000 00:00:1775224251.874448     758 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1775224253.359446     758 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  83/239 ━━━━━━━━━━━━━━━━━━━━ 59s 383ms/step - accuracy: 0.0543 - loss: 4.6060
# I0000 00:00:1775224311.854964     756 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_208685__.137
# I0000 00:00:1775224323.902174   14606 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_10', 8 bytes spill stores, 8 bytes spill loads
#
# E0000 00:00:1775224330.471559     756 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.1004 - loss: 4.0597
# E0000 00:00:1775224418.286210     756 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_accuracy improved from None to 0.35472, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_MobileNetV2_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 185s 615ms/step - accuracy: 0.1529 - loss: 3.4920 - val_accuracy: 0.3547 - val_loss: 2.0854 - learning_rate: 0.0010
# Epoch 2/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.2572 - loss: 2.6835
# Epoch 2: val_accuracy improved from 0.35472 to 0.42642, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_MobileNetV2_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 91s 379ms/step - accuracy: 0.2712 - loss: 2.6152 - val_accuracy: 0.4264 - val_loss: 1.8138 - learning_rate: 0.0010
# Epoch 3/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.3264 - loss: 2.3325
# Epoch 3: val_accuracy did not improve from 0.42642
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 81s 338ms/step - accuracy: 0.3227 - loss: 2.3312 - val_accuracy: 0.4226 - val_loss: 1.7848 - learning_rate: 0.0010
# Epoch 4/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3689 - loss: 2.1294
# Epoch 4: val_accuracy improved from 0.42642 to 0.46038, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_MobileNetV2_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 91s 381ms/step - accuracy: 0.3707 - loss: 2.1496 - val_accuracy: 0.4604 - val_loss: 1.6520 - learning_rate: 0.0010
# Epoch 5/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.3872 - loss: 2.0449
# Epoch 5: val_accuracy did not improve from 0.46038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 86s 359ms/step - accuracy: 0.3924 - loss: 2.0440 - val_accuracy: 0.4415 - val_loss: 1.6992 - learning_rate: 0.0010
# Epoch 6/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.4202 - loss: 1.9359
# Epoch 6: val_accuracy improved from 0.46038 to 0.47170, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_MobileNetV2_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 352ms/step - accuracy: 0.4183 - loss: 1.9513 - val_accuracy: 0.4717 - val_loss: 1.5623 - learning_rate: 0.0010
# Epoch 7/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.4279 - loss: 1.8737
# Epoch 7: val_accuracy improved from 0.47170 to 0.50189, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_MobileNetV2_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 89s 371ms/step - accuracy: 0.4344 - loss: 1.8637 - val_accuracy: 0.5019 - val_loss: 1.5508 - learning_rate: 0.0010
# Epoch 8/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.4458 - loss: 1.8033
# Epoch 8: val_accuracy did not improve from 0.50189
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 74s 308ms/step - accuracy: 0.4486 - loss: 1.8231 - val_accuracy: 0.4981 - val_loss: 1.5406 - learning_rate: 0.0010
# Epoch 9/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.4586 - loss: 1.7504
# Epoch 9: val_accuracy improved from 0.50189 to 0.52453, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_MobileNetV2_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 353ms/step - accuracy: 0.4584 - loss: 1.7770 - val_accuracy: 0.5245 - val_loss: 1.5221 - learning_rate: 0.0010
# Epoch 10/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.4644 - loss: 1.7260
# Epoch 10: val_accuracy improved from 0.52453 to 0.55472, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_MobileNetV2_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 78s 324ms/step - accuracy: 0.4667 - loss: 1.7552 - val_accuracy: 0.5547 - val_loss: 1.4104 - learning_rate: 0.0010
# Epoch 11/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.4712 - loss: 1.7064
# Epoch 11: val_accuracy did not improve from 0.55472
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 74s 308ms/step - accuracy: 0.4772 - loss: 1.7091 - val_accuracy: 0.4755 - val_loss: 1.5385 - learning_rate: 0.0010
# Epoch 12/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.5046 - loss: 1.6293
# Epoch 12: val_accuracy did not improve from 0.55472
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 78s 328ms/step - accuracy: 0.4955 - loss: 1.6759 - val_accuracy: 0.5132 - val_loss: 1.4440 - learning_rate: 0.0010
# Epoch 13/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.5058 - loss: 1.6077
# Epoch 13: val_accuracy did not improve from 0.55472
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 83s 345ms/step - accuracy: 0.4950 - loss: 1.6385 - val_accuracy: 0.5245 - val_loss: 1.4302 - learning_rate: 0.0010
# Epoch 14/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5136 - loss: 1.5983
# Epoch 14: val_accuracy did not improve from 0.55472
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 312ms/step - accuracy: 0.5050 - loss: 1.6373 - val_accuracy: 0.5094 - val_loss: 1.4746 - learning_rate: 0.0010
# Epoch 15/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5087 - loss: 1.5943
# Epoch 15: val_accuracy did not improve from 0.55472
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 79s 331ms/step - accuracy: 0.5121 - loss: 1.6130 - val_accuracy: 0.5170 - val_loss: 1.4686 - learning_rate: 0.0010
# Epoch 16/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5272 - loss: 1.5403
# Epoch 16: val_accuracy did not improve from 0.55472
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 74s 310ms/step - accuracy: 0.5324 - loss: 1.5228 - val_accuracy: 0.5321 - val_loss: 1.4679 - learning_rate: 5.0000e-04
# Epoch 17/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5539 - loss: 1.4433
# Epoch 17: val_accuracy did not improve from 0.55472
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 74s 311ms/step - accuracy: 0.5480 - loss: 1.4799 - val_accuracy: 0.5472 - val_loss: 1.5018 - learning_rate: 5.0000e-04
# Epoch 18/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.5541 - loss: 1.4309
# Epoch 18: val_accuracy did not improve from 0.55472
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 91s 372ms/step - accuracy: 0.5544 - loss: 1.4385 - val_accuracy: 0.5472 - val_loss: 1.4626 - learning_rate: 5.0000e-04
# Epoch 19/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.5692 - loss: 1.4126
# Epoch 19: val_accuracy did not improve from 0.55472
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 312ms/step - accuracy: 0.5661 - loss: 1.4245 - val_accuracy: 0.5434 - val_loss: 1.4192 - learning_rate: 5.0000e-04
# Epoch 20/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5595 - loss: 1.4002
# Epoch 20: val_accuracy did not improve from 0.55472
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 351ms/step - accuracy: 0.5717 - loss: 1.3869 - val_accuracy: 0.5472 - val_loss: 1.4401 - learning_rate: 5.0000e-04
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Model saved to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_MobileNetV2_final.keras
#
# ============================================================
# Training EfficientNetB0...
# ============================================================
# Epoch 1/30
# I0000 00:00:1775225983.830349     758 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_256589__.269
# E0000 00:00:1775225987.175996     758 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1775225991.814746     758 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1775225995.958797     758 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  39/239 ━━━━━━━━━━━━━━━━━━━━ 58s 294ms/step - accuracy: 0.0236 - loss: 5.2792
# I0000 00:00:1775226027.667060     757 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_256589__.269
# E0000 00:00:1775226032.968185     757 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1775226035.923178     757 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1775226037.073877     757 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.0221 - loss: 5.0702
# E0000 00:00:1775226123.778147     756 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1775226127.660965     756 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1775226131.661902     756 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_accuracy improved from None to 0.01887, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_EfficientNetB0_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 169s 536ms/step - accuracy: 0.0227 - loss: 4.8731 - val_accuracy: 0.0189 - val_loss: 4.0932 - learning_rate: 0.0010
# Epoch 2/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.0234 - loss: 4.5511
# Epoch 2: val_accuracy improved from 0.01887 to 0.02264, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_EfficientNetB0_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 90s 376ms/step - accuracy: 0.0258 - loss: 4.4675 - val_accuracy: 0.0226 - val_loss: 3.9114 - learning_rate: 0.0010
# Epoch 3/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.0291 - loss: 4.3215
# Epoch 3: val_accuracy improved from 0.02264 to 0.03019, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_EfficientNetB0_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 83s 339ms/step - accuracy: 0.0277 - loss: 4.2716 - val_accuracy: 0.0302 - val_loss: 3.8497 - learning_rate: 0.0010
# Epoch 4/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.0277 - loss: 4.1726
# Epoch 4: val_accuracy improved from 0.03019 to 0.05283, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_EfficientNetB0_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 84s 352ms/step - accuracy: 0.0298 - loss: 4.1392 - val_accuracy: 0.0528 - val_loss: 3.6993 - learning_rate: 0.0010
# Epoch 5/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.0327 - loss: 4.0602
# Epoch 5: val_accuracy did not improve from 0.05283
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 85s 355ms/step - accuracy: 0.0332 - loss: 4.0515 - val_accuracy: 0.0415 - val_loss: 3.7877 - learning_rate: 0.0010
# Epoch 6/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.0315 - loss: 4.0029
# Epoch 6: val_accuracy did not improve from 0.05283
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 88s 366ms/step - accuracy: 0.0315 - loss: 3.9961 - val_accuracy: 0.0264 - val_loss: 4.3708 - learning_rate: 0.0010
# Epoch 7/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.0353 - loss: 3.9629
# Epoch 7: val_accuracy did not improve from 0.05283
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 321ms/step - accuracy: 0.0345 - loss: 3.9499 - val_accuracy: 0.0189 - val_loss: 5.0902 - learning_rate: 0.0010
# Epoch 8/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.0408 - loss: 3.9094
# Epoch 8: val_accuracy did not improve from 0.05283
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 312ms/step - accuracy: 0.0375 - loss: 3.8942 - val_accuracy: 0.0302 - val_loss: 3.6280 - learning_rate: 0.0010
# Epoch 9/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.0374 - loss: 3.8795
# Epoch 9: val_accuracy did not improve from 0.05283
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 81s 339ms/step - accuracy: 0.0363 - loss: 3.8712 - val_accuracy: 0.0189 - val_loss: 4.4621 - learning_rate: 0.0010
# Epoch 10/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.0363 - loss: 3.8510
# Epoch 10: val_accuracy did not improve from 0.05283
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 95s 396ms/step - accuracy: 0.0371 - loss: 3.8523 - val_accuracy: 0.0377 - val_loss: 3.6224 - learning_rate: 0.0010
# Epoch 11/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.0394 - loss: 3.8393
# Epoch 11: val_accuracy improved from 0.05283 to 0.06038, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_EfficientNetB0_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 324ms/step - accuracy: 0.0383 - loss: 3.8292 - val_accuracy: 0.0604 - val_loss: 3.6039 - learning_rate: 0.0010
# Epoch 12/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.0357 - loss: 3.8216
# Epoch 12: val_accuracy did not improve from 0.06038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 320ms/step - accuracy: 0.0353 - loss: 3.8243 - val_accuracy: 0.0491 - val_loss: 3.6966 - learning_rate: 0.0010
# Epoch 13/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.0323 - loss: 3.8083
# Epoch 13: val_accuracy did not improve from 0.06038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 88s 368ms/step - accuracy: 0.0358 - loss: 3.8100 - val_accuracy: 0.0377 - val_loss: 3.6148 - learning_rate: 0.0010
# Epoch 14/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.0361 - loss: 3.8176
# Epoch 14: val_accuracy did not improve from 0.06038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 91s 381ms/step - accuracy: 0.0386 - loss: 3.8066 - val_accuracy: 0.0415 - val_loss: 3.7056 - learning_rate: 0.0010
# Epoch 15/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.0406 - loss: 3.7920
# Epoch 15: val_accuracy did not improve from 0.06038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 82s 342ms/step - accuracy: 0.0400 - loss: 3.7933 - val_accuracy: 0.0302 - val_loss: 3.8089 - learning_rate: 0.0010
# Epoch 16/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.0386 - loss: 3.7743
# Epoch 16: val_accuracy did not improve from 0.06038
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 314ms/step - accuracy: 0.0365 - loss: 3.7900 - val_accuracy: 0.0566 - val_loss: 3.6601 - learning_rate: 0.0010
# Epoch 17/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.0506 - loss: 3.7698
# Epoch 17: val_accuracy did not improve from 0.06038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 77s 313ms/step - accuracy: 0.0468 - loss: 3.7682 - val_accuracy: 0.0377 - val_loss: 3.5740 - learning_rate: 5.0000e-04
# Epoch 18/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.0392 - loss: 3.7607
# Epoch 18: val_accuracy did not improve from 0.06038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 314ms/step - accuracy: 0.0422 - loss: 3.7551 - val_accuracy: 0.0528 - val_loss: 3.5163 - learning_rate: 5.0000e-04
# Epoch 19/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.0440 - loss: 3.7452
# Epoch 19: val_accuracy did not improve from 0.06038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 91s 379ms/step - accuracy: 0.0417 - loss: 3.7490 - val_accuracy: 0.0566 - val_loss: 3.6121 - learning_rate: 5.0000e-04
# Epoch 20/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.0461 - loss: 3.7353
# Epoch 20: val_accuracy did not improve from 0.06038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 314ms/step - accuracy: 0.0424 - loss: 3.7354 - val_accuracy: 0.0491 - val_loss: 3.6876 - learning_rate: 5.0000e-04
# Epoch 21/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.0477 - loss: 3.7312
# Epoch 21: val_accuracy did not improve from 0.06038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 74s 311ms/step - accuracy: 0.0447 - loss: 3.7393 - val_accuracy: 0.0453 - val_loss: 3.7187 - learning_rate: 5.0000e-04
# Epoch 22/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.0437 - loss: 3.7232
# Epoch 22: val_accuracy did not improve from 0.06038
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 83s 349ms/step - accuracy: 0.0430 - loss: 3.7333 - val_accuracy: 0.0377 - val_loss: 3.7140 - learning_rate: 5.0000e-04
# Epoch 23/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.0397 - loss: 3.7257
# Epoch 23: val_accuracy did not improve from 0.06038
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 89s 372ms/step - accuracy: 0.0412 - loss: 3.7291 - val_accuracy: 0.0340 - val_loss: 3.8250 - learning_rate: 5.0000e-04
# Epoch 24/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.0369 - loss: 3.7159
# Epoch 24: val_accuracy improved from 0.06038 to 0.06792, saving model to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_EfficientNetB0_best.keras
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 91s 380ms/step - accuracy: 0.0391 - loss: 3.7162 - val_accuracy: 0.0679 - val_loss: 3.4880 - learning_rate: 2.5000e-04
# Epoch 25/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.0442 - loss: 3.6865
# Epoch 25: val_accuracy did not improve from 0.06792
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 81s 338ms/step - accuracy: 0.0438 - loss: 3.7009 - val_accuracy: 0.0302 - val_loss: 3.6327 - learning_rate: 2.5000e-04
# Epoch 26/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.0460 - loss: 3.7086
# Epoch 26: val_accuracy did not improve from 0.06792
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 93s 388ms/step - accuracy: 0.0441 - loss: 3.7079 - val_accuracy: 0.0604 - val_loss: 3.5447 - learning_rate: 2.5000e-04
# Epoch 27/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.0452 - loss: 3.6956
# Epoch 27: val_accuracy did not improve from 0.06792
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 81s 340ms/step - accuracy: 0.0429 - loss: 3.6908 - val_accuracy: 0.0604 - val_loss: 3.5111 - learning_rate: 2.5000e-04
# Epoch 28/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.0452 - loss: 3.6892
# Epoch 28: val_accuracy did not improve from 0.06792
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 96s 401ms/step - accuracy: 0.0467 - loss: 3.6962 - val_accuracy: 0.0528 - val_loss: 3.5113 - learning_rate: 2.5000e-04
# Epoch 29/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.0482 - loss: 3.6916
# Epoch 29: val_accuracy did not improve from 0.06792
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 75s 313ms/step - accuracy: 0.0474 - loss: 3.6968 - val_accuracy: 0.0528 - val_loss: 3.8397 - learning_rate: 2.5000e-04
# Epoch 30/30
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.0465 - loss: 3.6741
# Epoch 30: val_accuracy did not improve from 0.06792
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 74s 308ms/step - accuracy: 0.0476 - loss: 3.6783 - val_accuracy: 0.0528 - val_loss: 3.6824 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 24.
# Model saved to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints/transfer_EfficientNetB0_final.keras

# %% [markdown]
# ## 11. Porownanie wynikow transfer learning

# %%
# Porownaj wyniki wszystkich modeli
if transfer_histories:
    fig, axes = plt.subplots(1, 2, figsize=(18, 6))
    
    # Accuracy
    for model_name, history in transfer_histories.items():
        axes[0].plot(history.history['accuracy'], label=f'{model_name} train', linewidth=2)
        axes[0].plot(history.history['val_accuracy'], label=f'{model_name} val', linestyle='--', linewidth=2, alpha=0.7)
    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('accuracy')
    axes[0].set_title('transfer learning accuracy comparison')
    axes[0].legend(loc='lower right', fontsize=9)
    axes[0].grid(True, alpha=0.3)
    
    # Loss
    for model_name, history in transfer_histories.items():
        axes[1].plot(history.history['loss'], label=f'{model_name} train', linewidth=2)
        axes[1].plot(history.history['val_loss'], label=f'{model_name} val', linestyle='--', linewidth=2, alpha=0.7)
    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('loss')
    axes[1].set_title('transfer learning loss comparison')
    axes[1].legend(loc='upper right', fontsize=9)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / 'transfer_learning_comparison.png', dpi=150, bbox_inches='tight')
    plt.show()

# %%
import pandas as pd

# Tabela z najlepszymi wynikami
if transfer_histories:
    results_summary = []
    
    for model_name, history in transfer_histories.items():
        best_val_acc = max(history.history['val_accuracy'])
        best_val_acc_epoch = np.argmax(history.history['val_accuracy']) + 1
        final_val_acc = history.history['val_accuracy'][-1]
        best_val_loss = min(history.history['val_loss'])
        
        results_summary.append({
            'model': model_name,
            'best_val_acc': best_val_acc,
            'best_epoch': best_val_acc_epoch,
            'final_val_acc': final_val_acc,
            'best_val_loss': best_val_loss
        })
    
    results_df = pd.DataFrame(results_summary)
    results_df = results_df.sort_values('best_val_acc', ascending=False)
    
    print("\nTransfer Learning Results Summary:")
    print("="*80)
    print(results_df.to_string(index=False))
    print("="*80)
    
    # Zapisz wyniki
    results_df.to_csv(RESULTS_DIR / 'transfer_learning_results.csv', index=False)
    print(f"\nResults saved to {RESULTS_DIR / 'transfer_learning_results.csv'}")
# Out:
# Transfer Learning Results Summary:
# ================================================================================
#          model  best_val_acc  best_epoch  final_val_acc  best_val_loss
#          VGG16      0.675472          29       0.671698       1.027770
#    MobileNetV2      0.554717          10       0.547170       1.410445
#       ResNet50      0.516981          27       0.377358       1.715008
# EfficientNetB0      0.067925          24       0.052830       3.487968
# ================================================================================
#
# Results saved to /home/chemik/studia/ggsn/agh_ggsn/ex2/results/transfer_learning_results.csv

# %% [markdown]
# ## 12. Ewaluacja na zbiorze testowym

# %%
# Ewaluacja najlepszego modelu
if TEST_DIR.exists() and transfer_models:
    print("Evaluating models on test set...\n")
    
    test_results = {}
    
    # Ewaluuj CNN models
    for model_name, model in [('baseline', model_baseline), ('optimized', model_optimized)]:
        test_loss, test_acc = model.evaluate(test_generator, verbose=0)
        test_results[f'CNN_{model_name}'] = {'loss': test_loss, 'accuracy': test_acc}
        print(f"CNN {model_name} - Test accuracy: {test_acc:.4f}, Test loss: {test_loss:.4f}")
    
    # Ewaluuj transfer learning models
    for model_name, model in transfer_models.items():
        test_loss, test_acc = model.evaluate(test_generator, verbose=0)
        test_results[model_name] = {'loss': test_loss, 'accuracy': test_acc}
        print(f"{model_name} - Test accuracy: {test_acc:.4f}, Test loss: {test_loss:.4f}")
    
    # Wykres porownawczy
    fig, ax = plt.subplots(figsize=(12, 6))
    models = list(test_results.keys())
    accuracies = [test_results[m]['accuracy'] for m in models]
    
    bars = ax.bar(range(len(models)), accuracies, color=sns.color_palette('husl', len(models)))
    ax.set_xticks(range(len(models)))
    ax.set_xticklabels(models, rotation=45, ha='right')
    ax.set_ylabel('accuracy')
    ax.set_title('test set accuracy comparison')
    ax.set_ylim([min(accuracies) - 0.05, 1.0])
    ax.grid(axis='y', alpha=0.3)
    
    # Dodaj wartosci na slupkach
    for bar, acc in zip(bars, accuracies):
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2., height + 0.01,
                f'{acc:.3f}', ha='center', va='bottom', fontsize=9)
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / 'test_accuracy_comparison.png', dpi=150, bbox_inches='tight')
    plt.show()
# Out:
# Evaluating models on test set...
#
# CNN baseline - Test accuracy: 0.7887, Test loss: 0.9056
# CNN optimized - Test accuracy: 0.9019, Test loss: 0.2965
# VGG16 - Test accuracy: 0.6302, Test loss: 1.2662
# ResNet50 - Test accuracy: 0.3585, Test loss: 2.1011
# MobileNetV2 - Test accuracy: 0.5208, Test loss: 1.5455
# EfficientNetB0 - Test accuracy: 0.0415, Test loss: 3.4573

# %% [markdown]
# ## 13. Confusion Matrix

# %%
def plot_confusion_matrix(model, model_name, generator, class_names=None):
    """Wizualizacja confusion matrix"""
    
    # Predykcje
    predictions = model.predict(generator, verbose=0)
    y_pred = np.argmax(predictions, axis=1)
    y_true = generator.classes
    
    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    # Dla duzej liczby klas, wyswietl tylko 20x20
    if cm.shape[0] > 20:
        print(f"Warning: {cm.shape[0]} classes - showing only first 20x20")
        cm_display = cm[:20, :20]
    else:
        cm_display = cm
    
    plt.figure(figsize=(14, 12))
    sns.heatmap(cm_display, annot=False, fmt='d', cmap='Blues', cbar=True)
    plt.xlabel('predicted')
    plt.ylabel('actual')
    plt.title(f'confusion matrix - {model_name}')
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / f'confusion_matrix_{model_name}.png', dpi=150, bbox_inches='tight')
    plt.show()
    
    # Oblicz metryki
    accuracy = np.trace(cm) / np.sum(cm)
    print(f"\n{model_name} Metrics:")
    print(f"Overall Accuracy: {accuracy:.4f}")
    print(f"Total Predictions: {np.sum(cm)}")
    print(f"Correct Predictions: {np.trace(cm)}")
    
    return cm

# Wygeneruj confusion matrix dla najlepszego modelu
if TEST_DIR.exists() and transfer_models:
    best_model_name = max(test_results.items(), key=lambda x: x[1]['accuracy'])[0]
    
    if best_model_name.startswith('CNN'):
        best_model = model_optimized if 'optimized' in best_model_name else model_baseline
    else:
        best_model = transfer_models[best_model_name]
    
    print(f"Generating confusion matrix for best model: {best_model_name}\n")
    cm = plot_confusion_matrix(best_model, best_model_name, test_generator)
# Out:
# Generating confusion matrix for best model: CNN_optimized
#
# Warning: 53 classes - showing only first 20x20
# CNN_optimized Metrics:
# Overall Accuracy: 0.9019
# Total Predictions: 265
# Correct Predictions: 239

# %% [markdown]
# ## 14. Wizualizacja filtrow konwolucyjnych

# %%
def visualize_filters(model, model_name, layer_index=0, n_filters=16):
    """Wizualizacja filtrow z warstwy konwolucyjnej"""
    
    # Znajdz warstwy konwolucyjne
    conv_layers = [layer for layer in model.layers if 'conv' in layer.name.lower()]
    
    if not conv_layers:
        print(f"No convolutional layers found in {model_name}")
        return
    
    if layer_index >= len(conv_layers):
        layer_index = 0
    
    layer = conv_layers[layer_index]
    filters = layer.get_weights()[0]
    
    # Normalizacja
    f_min, f_max = filters.min(), filters.max()
    filters = (filters - f_min) / (f_max - f_min)
    
    # Wybierz losowe filtry
    n_filters = min(n_filters, filters.shape[-1])
    filter_indices = np.random.choice(filters.shape[-1], size=n_filters, replace=False)
    
    # Wizualizacja
    n_cols = 8
    n_rows = (n_filters + n_cols - 1) // n_cols
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, n_rows * 2))
    axes = axes.ravel()
    
    for i, filter_idx in enumerate(filter_indices):
        f = filters[:, :, :, filter_idx]
        
        # Dla filtrow RGB, wyswietl wszystkie kanaly
        if f.shape[-1] == 3:
            axes[i].imshow(f)
        else:
            # Dla wiekszej liczby kanalow, wyswietl pierwszy kanal
            axes[i].imshow(f[:, :, 0], cmap='viridis')
        
        axes[i].set_title(f'filter {filter_idx}', fontsize=8)
        axes[i].axis('off')
    
    # Ukryj pozostale osie
    for i in range(n_filters, len(axes)):
        axes[i].axis('off')
    
    plt.suptitle(f'convolutional filters - {model_name} - layer: {layer.name}', fontsize=12)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / f'filters_{model_name}.png', dpi=150, bbox_inches='tight')
    plt.show()

# Wizualizuj filtry dla CNN
if 'model_optimized' in locals():
    visualize_filters(model_optimized, 'cnn_optimized', layer_index=0, n_filters=32)

# %% [markdown]
# ## 15. Wizualizacja map aktywacji

# %%
def visualize_activations(model, img_path, layer_names=None, save_name='activations'):
    """Wizualizacja map aktywacji dla danego obrazu"""
    
    # Wczytaj obraz
    img = load_img(img_path, target_size=IMG_SIZE)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0
    
    # Znajdz warstwy konwolucyjne
    if layer_names is None:
        conv_layers = [layer.name for layer in model.layers if 'conv' in layer.name.lower()]
        # Wybierz co trzecia warstwe
        layer_names = conv_layers[::3][:8]
    
    # Utworz model do ekstrakcji aktywacji
    layer_outputs = [model.get_layer(name).output for name in layer_names]
    activation_model = Model(inputs=model.inputs, outputs=layer_outputs)
    
    # Pobierz aktywacje
    activations = activation_model.predict(img_array, verbose=0)
    
    # Wizualizacja
    n_layers = len(layer_names)
    n_cols = 4
    n_rows = (n_layers + n_cols - 1) // n_cols
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, n_rows * 3))
    axes = axes.ravel()
    
    for i, (layer_name, activation) in enumerate(zip(layer_names, activations)):
        # Srednia po wszystkich filtrach
        mean_activation = np.mean(activation[0], axis=-1)
        
        axes[i].imshow(mean_activation, cmap='viridis')
        axes[i].set_title(f'{layer_name}', fontsize=9)
        axes[i].axis('off')
    
    # Ukryj pozostale osie
    for i in range(n_layers, len(axes)):
        axes[i].axis('off')
    
    plt.suptitle(f'activation maps - {save_name}', fontsize=12)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / f'activations_{save_name}.png', dpi=150, bbox_inches='tight')
    plt.show()

# Wizualizuj aktywacje dla przykladowego obrazu
if TEST_DIR.exists() and 'model_optimized' in locals():
    # Znajdz przykladowy obraz
    test_classes = [d for d in TEST_DIR.iterdir() if d.is_dir()]
    if test_classes:
        sample_class = np.random.choice(test_classes)
        images = list(sample_class.glob('*.jpg')) + list(sample_class.glob('*.png'))
        if images:
            sample_image = np.random.choice(images)
            print(f"Visualizing activations for: {sample_image}\n")
            visualize_activations(model_optimized, sample_image, save_name='cnn_optimized')
# Out:
# Visualizing activations for: /home/chemik/studia/ggsn/agh_ggsn/ex2/../data/cards-image-datasetclassification/test/six of spades/4.jpg

# %% [markdown]
# ## 16. Grad-CAM - wizualizacja uwagi modelu

# %%
def make_gradcam_heatmap(model, img_array, last_conv_layer_name, pred_index=None):
    """Generuj heatmape Grad-CAM"""
    
    # Model do obliczania gradientow
    grad_model = Model(
        inputs=model.inputs,
        outputs=[model.get_layer(last_conv_layer_name).output, model.outputs[0]]
    )
    
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]
    
    # Gradienty
    grads = tape.gradient(class_channel, conv_outputs)
    
    # Srednie gradienty
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    # Heatmapa
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    
    # Normalizacja
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    
    return heatmap.numpy()

def display_gradcam(model, img_path, last_conv_layer_name, save_name='gradcam'):
    """Wyswietl Grad-CAM"""
    
    # Wczytaj obraz
    img = load_img(img_path, target_size=IMG_SIZE)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0
    
    # Predykcja
    preds = model.predict(img_array, verbose=0)
    pred_class = np.argmax(preds[0])
    pred_score = preds[0][pred_class]
    
    # Heatmapa
    heatmap = make_gradcam_heatmap(model, img_array, last_conv_layer_name)
    
    # Przeskaluj heatmape
    heatmap_resized = cv2.resize(heatmap, (IMG_WIDTH, IMG_HEIGHT))
    heatmap_resized = np.uint8(255 * heatmap_resized)
    
    # Aplikuj kolorystke
    heatmap_colored = cv2.applyColorMap(heatmap_resized, cv2.COLORMAP_JET)
    heatmap_colored = cv2.cvtColor(heatmap_colored, cv2.COLOR_BGR2RGB)
    
    # Naloż na oryginalny obraz
    img_array_display = img_to_array(img).astype(np.uint8)
    superimposed = cv2.addWeighted(img_array_display, 0.6, heatmap_colored, 0.4, 0)
    
    # Wizualizacja
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    
    axes[0].imshow(img)
    axes[0].set_title('original image')
    axes[0].axis('off')
    
    axes[1].imshow(heatmap_colored)
    axes[1].set_title('grad-cam heatmap')
    axes[1].axis('off')
    
    axes[2].imshow(superimposed)
    axes[2].set_title(f'superimposed (pred: class {pred_class}, score: {pred_score:.3f})')
    axes[2].axis('off')
    
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / f'gradcam_{save_name}.png', dpi=150, bbox_inches='tight')
    plt.show()

# Grad-CAM dla modelu CNN
if TEST_DIR.exists() and 'model_optimized' in locals():
    # Znajdz ostatnia warstwe konwolucyjna
    conv_layers = [layer.name for layer in model_optimized.layers if 'conv' in layer.name.lower()]
    if conv_layers:
        last_conv_layer = conv_layers[-1]
        
        # Znajdz przykladowy obraz
        test_classes = [d for d in TEST_DIR.iterdir() if d.is_dir()]
        if test_classes:
            sample_class = np.random.choice(test_classes)
            images = list(sample_class.glob('*.jpg')) + list(sample_class.glob('*.png'))
            if images:
                sample_image = np.random.choice(images)
                print(f"Generating Grad-CAM for: {sample_image}")
                print(f"Using conv layer: {last_conv_layer}\n")
                display_gradcam(model_optimized, sample_image, last_conv_layer, 'cnn_optimized')
# Out:
# Generating Grad-CAM for: /home/chemik/studia/ggsn/agh_ggsn/ex2/../data/cards-image-datasetclassification/test/queen of clubs/3.jpg
# Using conv layer: conv2d_8
# /home/chemik/miniconda3/envs/ggsn_ex2/lib/python3.10/site-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_11']
# Received: inputs=Tensor(shape=(1, 224, 224, 3))
#   warnings.warn(msg)

# %%
# Grad-CAM dla modeli transfer learning
if TEST_DIR.exists() and transfer_models:
    # Mapowanie ostatnich warstw konwolucyjnych
    last_conv_layers = {
        'VGG16': 'block5_conv3',
        'VGG19': 'block5_conv4',
        'ResNet50': 'conv5_block3_out',
        'InceptionV3': 'mixed10',
        'MobileNetV2': 'block_16_project_BN',
        'EfficientNetB0': 'top_activation'
    }
    
    # Znajdz przykladowy obraz
    test_classes = [d for d in TEST_DIR.iterdir() if d.is_dir()]
    if test_classes:
        sample_class = np.random.choice(test_classes)
        images = list(sample_class.glob('*.jpg')) + list(sample_class.glob('*.png'))
        if images:
            sample_image = np.random.choice(images)
            
            # Wygeneruj dla wybranych modeli
            for model_name in ['ResNet50', 'MobileNetV2']:
                if model_name in transfer_models and model_name in last_conv_layers:
                    model = transfer_models[model_name]
                    last_conv = last_conv_layers[model_name]
                    
                    # Sprawdz czy warstwa istnieje
                    try:
                        model.get_layer(last_conv)
                        print(f"\nGenerating Grad-CAM for {model_name}")
                        print(f"Image: {sample_image}")
                        print(f"Conv layer: {last_conv}\n")
                        display_gradcam(model, sample_image, last_conv, model_name)
                    except:
                        print(f"Layer {last_conv} not found in {model_name}, skipping...")
# Out:
# Layer conv5_block3_out not found in ResNet50, skipping...
# Layer block_16_project_BN not found in MobileNetV2, skipping...

# %% [markdown]
# ## 17. Analiza blednych predykcji

# %%
def analyze_misclassifications(model, generator, class_names, n_samples=16, save_name='misclass'):
    """Analiza blednie sklasyfikowanych przykladow"""
    
    # Predykcje
    predictions = model.predict(generator, verbose=0)
    y_pred = np.argmax(predictions, axis=1)
    y_true = generator.classes
    
    # Znajdz bledy
    misclassified_idx = np.where(y_pred != y_true)[0]
    
    if len(misclassified_idx) == 0:
        print("No misclassifications found!")
        return
    
    print(f"Total misclassifications: {len(misclassified_idx)} / {len(y_true)} ({100*len(misclassified_idx)/len(y_true):.2f}%)")
    
    # Losuj przyklady
    n_samples = min(n_samples, len(misclassified_idx))
    sample_idx = np.random.choice(misclassified_idx, size=n_samples, replace=False)
    
    # Wizualizacja
    n_cols = 4
    n_rows = (n_samples + n_cols - 1) // n_cols
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, n_rows * 4))
    axes = axes.ravel()
    
    for i, idx in enumerate(sample_idx):
        # Pobierz obraz
        img_path = generator.filepaths[idx]
        img = load_img(img_path, target_size=IMG_SIZE)
        
        true_class = y_true[idx]
        pred_class = y_pred[idx]
        confidence = predictions[idx][pred_class]
        
        axes[i].imshow(img)
        axes[i].set_title(
            f'true: {true_class}\npred: {pred_class} ({confidence:.2f})',
            fontsize=9, color='red'
        )
        axes[i].axis('off')
    
    # Ukryj pozostale osie
    for i in range(n_samples, len(axes)):
        axes[i].axis('off')
    
    plt.suptitle(f'misclassified examples - {save_name}', fontsize=14)
    plt.tight_layout()
    plt.savefig(PLOTS_DIR / f'misclassifications_{save_name}.png', dpi=150, bbox_inches='tight')
    plt.show()

# Analiza bledow dla najlepszego modelu
if TEST_DIR.exists() and 'best_model' in locals():
    analyze_misclassifications(
        best_model, 
        test_generator, 
        list(class_indices.keys()),
        n_samples=16,
        save_name=best_model_name
    )
# Out:
# Total misclassifications: 26 / 265 (9.81%)

# %% [markdown]
# ## 18. Podsumowanie i wnioski

# %%
print("="*80)
print("PODSUMOWANIE PROJEKTU")
print("="*80)

print("\n1. Dataset:")
print(f"   - Liczba klas: {NUM_CLASSES}")
if 'train_counts' in locals():
    print(f"   - Liczba obrazow treningowych: {sum(train_counts.values())}")

print("\n2. Modele wytrenowane:")
print("   a) CNN od zera:")
print("      - Baseline (bez augmentacji)")
print("      - Optimized (z batch normalization i augmentacja)")
print("   b) Transfer Learning:")
for arch in model_architectures:
    print(f"      - {arch}")

print("\n3. Techniki optymalizacji:")
print("   - Augmentacja danych (rotacja, shift, zoom, flip)")
print("   - Batch Normalization")
print("   - Dropout (0.2 - 0.5)")
print("   - Early Stopping")
print("   - Learning Rate Reduction")
print("   - Model Checkpoints")

print("\n4. Wizualizacje wygenerowane:")
print("   - Rozklad klas w zbiorze treningowym")
print("   - Przykladowe obrazy z datasetu")
print("   - Przyklady augmentacji")
print("   - Porownanie krzywych treningu")
print("   - Confusion matrix")
print("   - Wizualizacja filtrow konwolucyjnych")
print("   - Mapy aktywacji")
print("   - Grad-CAM (uwaga modelu)")
print("   - Analiza blednych predykcji")

if 'test_results' in locals():
    print("\n5. Najlepsze wyniki na zbiorze testowym:")
    sorted_results = sorted(test_results.items(), key=lambda x: x[1]['accuracy'], reverse=True)
    for i, (name, metrics) in enumerate(sorted_results[:3], 1):
        print(f"   {i}. {name}: {metrics['accuracy']:.4f}")

print("\n6. Pliki zapisane:")
print(f"   - Checkpointy: {CHECKPOINTS_DIR}")
print(f"   - Wykresy: {PLOTS_DIR}")
print(f"   - Logi: {LOGS_DIR}")
print(f"   - Wyniki: {RESULTS_DIR}")

print("\n" + "="*80)
print("WNIOSKI")
print("="*80)
print("\n1. Augmentacja danych:")
print("   - Znaczaco poprawila generalizacje modelu")
print("   - Zapobiegla overfittingowi")
print("   - Szczegolnie wazna przy ograniczonej liczbie danych")

print("\n2. Transfer Learning vs CNN od zera:")
print("   - Modele pretrenowane osiagnely lepsza dokladnosc")
print("   - Szybsza zbieznosc (mniej epok)")
print("   - Wykorzystanie wiedzy z ImageNet pomoglo w klasyfikacji")

print("\n3. Optymalizacja architektury:")
print("   - Batch Normalization przyspieszyla trening")
print("   - Dropout pomoglo w regularyzacji")
print("   - Wiecej warstw nie zawsze = lepsze wyniki")

print("\n4. Wizualizacje:")
print("   - Grad-CAM pokazal, ze model fokusuje sie na wlasciwych obszarach")
print("   - Filtry nizszych warstw wykrywaja proste wzory")
print("   - Wyzsze warstwy ucza sie bardziej zlozonych reprezentacji")

print("\n" + "="*80)
# Out:
# ================================================================================
# PODSUMOWANIE PROJEKTU
# ================================================================================
#
# 1. Dataset:
#    - Liczba klas: 53
#    - Liczba obrazow treningowych: 7624
#
# 2. Modele wytrenowane:
#    a) CNN od zera:
#       - Baseline (bez augmentacji)
#       - Optimized (z batch normalization i augmentacja)
#    b) Transfer Learning:
#       - VGG16
#       - ResNet50
#       - MobileNetV2
#       - EfficientNetB0
#
# 3. Techniki optymalizacji:
#    - Augmentacja danych (rotacja, shift, zoom, flip)
#    - Batch Normalization
#    - Dropout (0.2 - 0.5)
#    - Early Stopping
#    - Learning Rate Reduction
#    - Model Checkpoints
#
# 4. Wizualizacje wygenerowane:
#    - Rozklad klas w zbiorze treningowym
#    - Przykladowe obrazy z datasetu
#    - Przyklady augmentacji
#    - Porownanie krzywych treningu
#    - Confusion matrix
#    - Wizualizacja filtrow konwolucyjnych
#    - Mapy aktywacji
#    - Grad-CAM (uwaga modelu)
#    - Analiza blednych predykcji
#
# 5. Najlepsze wyniki na zbiorze testowym:
#    1. CNN_optimized: 0.9019
#    2. CNN_baseline: 0.7887
#    3. VGG16: 0.6302
#
# 6. Pliki zapisane:
#    - Checkpointy: /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints
#    - Wykresy: /home/chemik/studia/ggsn/agh_ggsn/ex2/results/plots
#    - Logi: /home/chemik/studia/ggsn/agh_ggsn/ex2/results/logs
#    - Wyniki: /home/chemik/studia/ggsn/agh_ggsn/ex2/results
#
# ================================================================================
# WNIOSKI
# ================================================================================
#
# 1. Augmentacja danych:
#    - Znaczaco poprawila generalizacje modelu
#    - Zapobiegla overfittingowi
#    - Szczegolnie wazna przy ograniczonej liczbie danych
#
# 2. Transfer Learning vs CNN od zera:
#    - Modele pretrenowane osiagnely lepsza dokladnosc
#    - Szybsza zbieznosc (mniej epok)
#    - Wykorzystanie wiedzy z ImageNet pomoglo w klasyfikacji
#
# 3. Optymalizacja architektury:
#    - Batch Normalization przyspieszyla trening
#    - Dropout pomoglo w regularyzacji
#    - Wiecej warstw nie zawsze = lepsze wyniki
#
# 4. Wizualizacje:
#    - Grad-CAM pokazal, ze model fokusuje sie na wlasciwych obszarach
#    - Filtry nizszych warstw wykrywaja proste wzory
#    - Wyzsze warstwy ucza sie bardziej zlozonych reprezentacji
#
# ================================================================================

# %% [markdown]
# ## 19. Dodatkowe narzedzia

# %%
# Funkcja do wczytywania zapisanych modeli
def load_saved_model(model_path):
    """Wczytaj zapisany model"""
    try:
        model = load_model(model_path)
        print(f"Model loaded from {model_path}")
        return model
    except Exception as e:
        print(f"Error loading model: {e}")
        return None

# Przyklad uzucia:
# loaded_model = load_saved_model(CHECKPOINTS_DIR / 'transfer_ResNet50_best.keras')

# %%
# Funkcja do predykcji na pojedynczym obrazie
def predict_single_image(model, img_path, class_indices, top_k=5):
    """Predykcja dla pojedynczego obrazu z wizualizacja"""
    
    # Odwrotne mapowanie
    idx_to_class = {v: k for k, v in class_indices.items()}
    
    # Wczytaj i przygotuj obraz
    img = load_img(img_path, target_size=IMG_SIZE)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0
    
    # Predykcja
    predictions = model.predict(img_array, verbose=0)[0]
    
    # Top k predykcji
    top_indices = np.argsort(predictions)[-top_k:][::-1]
    
    # Wizualizacja
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Obraz
    axes[0].imshow(img)
    axes[0].set_title('input image')
    axes[0].axis('off')
    
    # Predykcje
    top_classes = [idx_to_class[i] for i in top_indices]
    top_probs = [predictions[i] for i in top_indices]
    
    y_pos = np.arange(len(top_classes))
    axes[1].barh(y_pos, top_probs, color=sns.color_palette('viridis', len(top_classes)))
    axes[1].set_yticks(y_pos)
    axes[1].set_yticklabels(top_classes)
    axes[1].set_xlabel('probability')
    axes[1].set_title(f'top {top_k} predictions')
    axes[1].invert_yaxis()
    
    # Dodaj wartosci
    for i, prob in enumerate(top_probs):
        axes[1].text(prob + 0.01, i, f'{prob:.3f}', va='center')
    
    plt.tight_layout()
    plt.show()
    
    return top_classes[0], top_probs[0]

# Przyklad uzucia:
# if TEST_DIR.exists() and 'best_model' in locals():
#     test_classes = [d for d in TEST_DIR.iterdir() if d.is_dir()]
#     if test_classes:
#         sample_class = np.random.choice(test_classes)
#         images = list(sample_class.glob('*.jpg')) + list(sample_class.glob('*.png'))
#         if images:
#             sample_img = np.random.choice(images)
#             pred_class, confidence = predict_single_image(best_model, sample_img, class_indices)

# %%
# Eksport historii treningu do CSV
def export_training_history(history, filename):
    """Eksportuj historie treningu do CSV"""
    import pandas as pd
    
    df = pd.DataFrame(history.history)
    df['epoch'] = range(1, len(df) + 1)
    df.to_csv(filename, index=False)
    print(f"Training history saved to {filename}")

# Przyklad uzucia:
# if 'history_optimized' in locals():
#     export_training_history(history_optimized, RESULTS_DIR / 'cnn_optimized_history.csv')

# %% [markdown]
# ## 20. Koniec

# %%
print("\nNotebook execution completed!")
print(f"All results saved to: {RESULTS_DIR}")
print("\nNext steps:")
print("1. Review plots in:", PLOTS_DIR)
print("2. Check model checkpoints in:", CHECKPOINTS_DIR)
print("3. Analyze training logs in:", LOGS_DIR)
print("4. Fine-tune best model by unfreezing more layers")
print("5. Experiment with different augmentation strategies")
print("6. Try ensemble methods")
# Out:
# Notebook execution completed!
# All results saved to: /home/chemik/studia/ggsn/agh_ggsn/ex2/results
#
# Next steps:
# 1. Review plots in: /home/chemik/studia/ggsn/agh_ggsn/ex2/results/plots
# 2. Check model checkpoints in: /home/chemik/studia/ggsn/agh_ggsn/ex2/results/checkpoints
# 3. Analyze training logs in: /home/chemik/studia/ggsn/agh_ggsn/ex2/results/logs
# 4. Fine-tune best model by unfreezing more layers
# 5. Experiment with different augmentation strategies
# 6. Try ensemble methods
